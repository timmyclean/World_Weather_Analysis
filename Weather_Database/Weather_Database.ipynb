# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.USe 'zip' function used to pair things
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 738

# %%
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.6.2.3
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print(url)

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create an empty list to hold the weather data.6.2.6
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current = city_weather["weather"][0]["description"]
        #6.2.5 
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_current})
#         break

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
#         pass
#         break

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | hithadhoo
# Processing Record 2 of Set 1 | hamilton
# Processing Record 3 of Set 1 | luderitz
# Processing Record 4 of Set 1 | turinskaya sloboda
# Processing Record 5 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 6 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 1 | karaul
# City not found. Skipping...
# Processing Record 8 of Set 1 | chokurdakh
# Processing Record 9 of Set 1 | bandarbeyla
# Processing Record 10 of Set 1 | port alfred
# Processing Record 11 of Set 1 | viedma
# Processing Record 12 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 13 of Set 1 | henties bay
# Processing Record 14 of Set 1 | north bend
# Processing Record 15 of Set 1 | kapaa
# Processing Record 16 of Set 1 | da nang
# Processing Record 17 of Set 1 | mataura
# Processing Record 18 of Set 1 | busselton
# Processing Record 19 of Set 1 | tarakan
# Processing Record 20 of Set 1 | saint-philippe
# Processing Record 21 of Set 1 | east london
# Processing Record 22 of Set 1 | codrington
# Processing Record 23 of Set 1 | ponta do sol
# Processing Record 24 of Set 1 | lufkin
# Processing Record 25 of Set 1 | grande riviere du nord
# Processing Record 26 of Set 1 | cidreira
# Processing Record 27 of Set 1 | rikitea
# Processing Record 28 of Set 1 | caravelas
# Processing Record 29 of Set 1 | cherskiy
# Processing Record 30 of Set 1 | karamay
# City not found. Skipping...
# Processing Record 31 of Set 1 | punta arenas
# Processing Record 32 of Set 1 | atuona
# Processing Record 33 of Set 1 | vardo
# Processing Record 34 of Set 1 | izberbash
# Processing Record 35 of Set 1 | hobart
# Processing Record 36 of Set 1 | coihaique
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 39 of Set 1 | roebourne
# Processing Record 40 of Set 1 | wuwei
# Processing Record 41 of Set 1 | hermanus
# Processing Record 42 of Set 1 | brigantine
# Processing Record 43 of Set 1 | isangel
# Processing Record 44 of Set 1 | mar del plata
# Processing Record 45 of Set 1 | ushuaia
# Processing Record 46 of Set 1 | havre-saint-pierre
# Processing Record 47 of Set 1 | dalnegorsk
# Processing Record 48 of Set 1 | talnakh
# Processing Record 49 of Set 1 | zhigansk
# Processing Record 50 of Set 1 | albany
# Processing Record 1 of Set 2 | vaini
# Processing Record 2 of Set 2 | chapais
# Processing Record 3 of Set 2 | samalaeulu
# City not found. Skipping...
# Processing Record 4 of Set 2 | mandalgovi
# Processing Record 5 of Set 2 | port elizabeth
# Processing Record 6 of Set 2 | namatanai
# Processing Record 7 of Set 2 | sedelnikovo
# City not found. Skipping...
# Processing Record 8 of Set 2 | cape town
# Processing Record 9 of Set 2 | carmen de carupa
# Processing Record 10 of Set 2 | makakilo city
# Processing Record 11 of Set 2 | sirnak
# Processing Record 12 of Set 2 | chuy
# Processing Record 13 of Set 2 | kodiak
# Processing Record 14 of Set 2 | anadyr
# Processing Record 15 of Set 2 | sitka
# Processing Record 16 of Set 2 | castro
# Processing Record 17 of Set 2 | baghdad
# Processing Record 18 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 19 of Set 2 | gold coast
# Processing Record 20 of Set 2 | bambous virieux
# Processing Record 21 of Set 2 | qaanaaq
# Processing Record 22 of Set 2 | nemuro
# Processing Record 23 of Set 2 | taree
# Processing Record 24 of Set 2 | georgetown
# Processing Record 25 of Set 2 | puerto ayora
# Processing Record 26 of Set 2 | komsomolskiy
# Processing Record 27 of Set 2 | biograd na moru
# Processing Record 28 of Set 2 | wewak
# Processing Record 29 of Set 2 | hilo
# Processing Record 30 of Set 2 | haines junction
# Processing Record 31 of Set 2 | lagoa
# Processing Record 32 of Set 2 | katherine
# Processing Record 33 of Set 2 | taoudenni
# Processing Record 34 of Set 2 | pevek
# Processing Record 35 of Set 2 | anuradhapura
# Processing Record 36 of Set 2 | tuktoyaktuk
# Processing Record 37 of Set 2 | aksu
# Processing Record 38 of Set 2 | new norfolk
# Processing Record 39 of Set 2 | kirakira
# Processing Record 40 of Set 2 | bredasdorp
# Processing Record 41 of Set 2 | general roca
# Processing Record 42 of Set 2 | polson
# Processing Record 43 of Set 2 | khatanga
# Processing Record 44 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 45 of Set 2 | pyay
# Processing Record 46 of Set 2 | bethel
# Processing Record 47 of Set 2 | barrow
# Processing Record 48 of Set 2 | lata
# Processing Record 49 of Set 2 | jamestown
# Processing Record 50 of Set 2 | elizabeth city
# Processing Record 1 of Set 3 | upernavik
# Processing Record 2 of Set 3 | nelson bay
# Processing Record 3 of Set 3 | altay
# Processing Record 4 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 5 of Set 3 | tukums
# Processing Record 6 of Set 3 | tezu
# Processing Record 7 of Set 3 | tabiauea
# City not found. Skipping...
# Processing Record 8 of Set 3 | lorengau
# Processing Record 9 of Set 3 | ransang
# Processing Record 10 of Set 3 | grindavik
# Processing Record 11 of Set 3 | mormugao
# Processing Record 12 of Set 3 | airai
# Processing Record 13 of Set 3 | zhanaozen
# Processing Record 14 of Set 3 | leningradskiy
# Processing Record 15 of Set 3 | hokitika
# Processing Record 16 of Set 3 | acapulco
# Processing Record 17 of Set 3 | tabou
# Processing Record 18 of Set 3 | poshekhonye
# Processing Record 19 of Set 3 | sur
# Processing Record 20 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 21 of Set 3 | taksimo
# Processing Record 22 of Set 3 | nanortalik
# Processing Record 23 of Set 3 | finschhafen
# Processing Record 24 of Set 3 | acari
# Processing Record 25 of Set 3 | marcona
# City not found. Skipping...
# Processing Record 26 of Set 3 | zdvinsk
# Processing Record 27 of Set 3 | boa vista
# Processing Record 28 of Set 3 | sao joao da barra
# Processing Record 29 of Set 3 | rio grande
# Processing Record 30 of Set 3 | bengkulu
# Processing Record 31 of Set 3 | nabire
# Processing Record 32 of Set 3 | coquimbo
# Processing Record 33 of Set 3 | gillette
# Processing Record 34 of Set 3 | corleone
# Processing Record 35 of Set 3 | mahebourg
# Processing Record 36 of Set 3 | varca
# Processing Record 37 of Set 3 | huarmey
# Processing Record 38 of Set 3 | ha tinh
# Processing Record 39 of Set 3 | astaneh-ye ashrafiyeh
# Processing Record 40 of Set 3 | antofagasta
# Processing Record 41 of Set 3 | mandello del lario
# Processing Record 42 of Set 3 | dikson
# Processing Record 43 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 44 of Set 3 | hailar
# Processing Record 45 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 3 | varhaug
# Processing Record 47 of Set 3 | gushi
# Processing Record 48 of Set 3 | souillac
# Processing Record 49 of Set 3 | mangawan
# Processing Record 50 of Set 3 | yagodnoye
# Processing Record 1 of Set 4 | kupang
# Processing Record 2 of Set 4 | ketchikan
# Processing Record 3 of Set 4 | petropavlovsk-kamchatskiy
# Processing Record 4 of Set 4 | tuatapere
# Processing Record 5 of Set 4 | ancud
# Processing Record 6 of Set 4 | iqaluit
# Processing Record 7 of Set 4 | yellowknife
# Processing Record 8 of Set 4 | mangrol
# Processing Record 9 of Set 4 | imbituba
# Processing Record 10 of Set 4 | linqiong
# Processing Record 11 of Set 4 | kavieng
# Processing Record 12 of Set 4 | avarua
# Processing Record 13 of Set 4 | victoria
# Processing Record 14 of Set 4 | nikolskoye
# Processing Record 15 of Set 4 | rawson
# Processing Record 16 of Set 4 | arraial do cabo
# Processing Record 17 of Set 4 | kyabram
# Processing Record 18 of Set 4 | matara
# Processing Record 19 of Set 4 | andapa
# Processing Record 20 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 21 of Set 4 | nome
# Processing Record 22 of Set 4 | sao filipe
# Processing Record 23 of Set 4 | hualmay
# Processing Record 24 of Set 4 | viligili
# City not found. Skipping...
# Processing Record 25 of Set 4 | aripuana
# Processing Record 26 of Set 4 | stromness
# Processing Record 27 of Set 4 | torbay
# Processing Record 28 of Set 4 | lebu
# Processing Record 29 of Set 4 | kuche
# City not found. Skipping...
# Processing Record 30 of Set 4 | kazerun
# Processing Record 31 of Set 4 | bonthe
# Processing Record 32 of Set 4 | zaysan
# Processing Record 33 of Set 4 | saint-michel-des-saints
# Processing Record 34 of Set 4 | kpandae
# Processing Record 35 of Set 4 | ponta delgada
# Processing Record 36 of Set 4 | muros
# Processing Record 37 of Set 4 | kamenskoye
# City not found. Skipping...
# Processing Record 38 of Set 4 | grottammare
# Processing Record 39 of Set 4 | monrovia
# Processing Record 40 of Set 4 | litovko
# Processing Record 41 of Set 4 | karachev
# Processing Record 42 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 43 of Set 4 | kaitangata
# Processing Record 44 of Set 4 | quesnel
# Processing Record 45 of Set 4 | dauphin
# Processing Record 46 of Set 4 | santa isabel do rio negro
# Processing Record 47 of Set 4 | inhambane
# Processing Record 48 of Set 4 | yerbogachen
# Processing Record 49 of Set 4 | selenginsk
# Processing Record 50 of Set 4 | altamira
# Processing Record 1 of Set 5 | hasaki
# Processing Record 2 of Set 5 | lompoc
# Processing Record 3 of Set 5 | sogdiondon
# City not found. Skipping...
# Processing Record 4 of Set 5 | ruteng
# Processing Record 5 of Set 5 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 5 | upata
# Processing Record 7 of Set 5 | laguna
# Processing Record 8 of Set 5 | cap-aux-meules
# Processing Record 9 of Set 5 | longyearbyen
# Processing Record 10 of Set 5 | itarema
# Processing Record 11 of Set 5 | gat
# Processing Record 12 of Set 5 | sumbawa
# City not found. Skipping...
# Processing Record 13 of Set 5 | vale da amoreira
# Processing Record 14 of Set 5 | san javier
# Processing Record 15 of Set 5 | paita
# Processing Record 16 of Set 5 | takoradi
# Processing Record 17 of Set 5 | saint-georges
# Processing Record 18 of Set 5 | owo
# Processing Record 19 of Set 5 | hvammstangi
# City not found. Skipping...
# Processing Record 20 of Set 5 | fortuna
# Processing Record 21 of Set 5 | kuandian
# Processing Record 22 of Set 5 | carballo
# Processing Record 23 of Set 5 | butaritari
# Processing Record 24 of Set 5 | vilyuysk
# Processing Record 25 of Set 5 | shaunavon
# Processing Record 26 of Set 5 | vila franca do campo
# Processing Record 27 of Set 5 | cooma
# Processing Record 28 of Set 5 | oktyabrskoye
# Processing Record 29 of Set 5 | tiksi
# Processing Record 30 of Set 5 | volksrust
# Processing Record 31 of Set 5 | la ronge
# Processing Record 32 of Set 5 | atar
# Processing Record 33 of Set 5 | palabuhanratu
# City not found. Skipping...
# Processing Record 34 of Set 5 | weinan
# Processing Record 35 of Set 5 | geraldton
# Processing Record 36 of Set 5 | emporia
# Processing Record 37 of Set 5 | ribeira grande
# Processing Record 38 of Set 5 | soe
# Processing Record 39 of Set 5 | sangueya
# Processing Record 40 of Set 5 | lavrentiya
# Processing Record 41 of Set 5 | marawi
# Processing Record 42 of Set 5 | lashio
# Processing Record 43 of Set 5 | severo-kurilsk
# Processing Record 44 of Set 5 | provideniya
# Processing Record 45 of Set 5 | kemijarvi
# Processing Record 46 of Set 5 | bud
# Processing Record 47 of Set 5 | maniitsoq
# Processing Record 48 of Set 5 | kieta
# Processing Record 49 of Set 5 | bur gabo
# City not found. Skipping...
# Processing Record 50 of Set 5 | guerrero negro
# Processing Record 1 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 6 | aflu
# City not found. Skipping...
# Processing Record 3 of Set 6 | inderborskiy
# City not found. Skipping...
# Processing Record 4 of Set 6 | kon tum
# Processing Record 5 of Set 6 | zharkovskiy
# Processing Record 6 of Set 6 | kuching
# Processing Record 7 of Set 6 | den helder
# Processing Record 8 of Set 6 | caxito
# Processing Record 9 of Set 6 | kirundo
# Processing Record 10 of Set 6 | rosario
# Processing Record 11 of Set 6 | buin
# Processing Record 12 of Set 6 | puerto el triunfo
# Processing Record 13 of Set 6 | harrison
# Processing Record 14 of Set 6 | maslovka
# Processing Record 15 of Set 6 | saldanha
# Processing Record 16 of Set 6 | teeli
# Processing Record 17 of Set 6 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 18 of Set 6 | waingapu
# Processing Record 19 of Set 6 | williams lake
# Processing Record 20 of Set 6 | kokstad
# Processing Record 21 of Set 6 | ngozi
# Processing Record 22 of Set 6 | ilulissat
# Processing Record 23 of Set 6 | buraydah
# Processing Record 24 of Set 6 | pousat
# City not found. Skipping...
# Processing Record 25 of Set 6 | ust-maya
# Processing Record 26 of Set 6 | tasiilaq
# Processing Record 27 of Set 6 | baykit
# Processing Record 28 of Set 6 | pacific grove
# Processing Record 29 of Set 6 | abu samrah
# Processing Record 30 of Set 6 | katsuura
# Processing Record 31 of Set 6 | port hardy
# Processing Record 32 of Set 6 | bantry
# Processing Record 33 of Set 6 | severinia
# Processing Record 34 of Set 6 | tucupita
# Processing Record 35 of Set 6 | mantua
# Processing Record 36 of Set 6 | eucaliptus
# Processing Record 37 of Set 6 | rocha
# Processing Record 38 of Set 6 | blenheim
# Processing Record 39 of Set 6 | clyde river
# Processing Record 40 of Set 6 | nioro
# Processing Record 41 of Set 6 | bambanglipuro
# Processing Record 42 of Set 6 | bara
# Processing Record 43 of Set 6 | saskylakh
# Processing Record 44 of Set 6 | ndiekro
# City not found. Skipping...
# Processing Record 45 of Set 6 | barra
# Processing Record 46 of Set 6 | namibe
# Processing Record 47 of Set 6 | los llanos de aridane
# Processing Record 48 of Set 6 | yomitan
# City not found. Skipping...
# Processing Record 49 of Set 6 | moanda
# Processing Record 50 of Set 6 | hobyo
# Processing Record 1 of Set 7 | westport
# Processing Record 2 of Set 7 | dawlatabad
# Processing Record 3 of Set 7 | san felipe
# Processing Record 4 of Set 7 | pinkafeld
# Processing Record 5 of Set 7 | faanui
# Processing Record 6 of Set 7 | alofi
# Processing Record 7 of Set 7 | cartagena
# Processing Record 8 of Set 7 | aklavik
# Processing Record 9 of Set 7 | kaeo
# Processing Record 10 of Set 7 | labutta
# City not found. Skipping...
# Processing Record 11 of Set 7 | gashua
# Processing Record 12 of Set 7 | sisimiut
# Processing Record 13 of Set 7 | srednekolymsk
# Processing Record 14 of Set 7 | esperance
# Processing Record 15 of Set 7 | coahuayana
# Processing Record 16 of Set 7 | carnarvon
# Processing Record 17 of Set 7 | maloshuyka
# City not found. Skipping...
# Processing Record 18 of Set 7 | mulchen
# Processing Record 19 of Set 7 | fort nelson
# Processing Record 20 of Set 7 | raga
# Processing Record 21 of Set 7 | kuvshinovo
# Processing Record 22 of Set 7 | gondanglegi
# Processing Record 23 of Set 7 | saint-leu
# Processing Record 24 of Set 7 | svendborg
# Processing Record 25 of Set 7 | zhezkazgan
# Processing Record 26 of Set 7 | northam
# Processing Record 27 of Set 7 | buqayq
# City not found. Skipping...
# Processing Record 28 of Set 7 | nouadhibou
# Processing Record 29 of Set 7 | mecca
# Processing Record 30 of Set 7 | punta alta
# Processing Record 31 of Set 7 | oktyabrskiy
# Processing Record 32 of Set 7 | ucluelet
# Processing Record 33 of Set 7 | quatre cocos
# Processing Record 34 of Set 7 | burica
# City not found. Skipping...
# Processing Record 35 of Set 7 | oranjemund
# Processing Record 36 of Set 7 | conde
# Processing Record 37 of Set 7 | ostersund
# Processing Record 38 of Set 7 | jerantut
# Processing Record 39 of Set 7 | vanimo
# Processing Record 40 of Set 7 | krasnoselkup
# Processing Record 41 of Set 7 | dalvik
# Processing Record 42 of Set 7 | husavik
# Processing Record 43 of Set 7 | ereymentau
# Processing Record 44 of Set 7 | weston
# Processing Record 45 of Set 7 | lichtenfels
# Processing Record 46 of Set 7 | bubaque
# Processing Record 47 of Set 7 | sussex
# Processing Record 48 of Set 7 | porto novo
# Processing Record 49 of Set 7 | achutupo
# Processing Record 50 of Set 7 | ocean city
# Processing Record 1 of Set 8 | chara
# Processing Record 2 of Set 8 | yar-sale
# Processing Record 3 of Set 8 | sangar
# Processing Record 4 of Set 8 | awbari
# Processing Record 5 of Set 8 | qasigiannguit
# Processing Record 6 of Set 8 | guanica
# Processing Record 7 of Set 8 | conakry
# Processing Record 8 of Set 8 | faya
# Processing Record 9 of Set 8 | kathmandu
# Processing Record 10 of Set 8 | korla
# Processing Record 11 of Set 8 | rennes
# Processing Record 12 of Set 8 | pangnirtung
# Processing Record 13 of Set 8 | camacha
# Processing Record 14 of Set 8 | sivaki
# Processing Record 15 of Set 8 | nizhnevartovsk
# Processing Record 16 of Set 8 | touros
# Processing Record 17 of Set 8 | qixia
# Processing Record 18 of Set 8 | kavaratti
# Processing Record 19 of Set 8 | sabang
# Processing Record 20 of Set 8 | dunedin
# Processing Record 21 of Set 8 | cayenne
# Processing Record 22 of Set 8 | thompson
# Processing Record 23 of Set 8 | te anau
# Processing Record 24 of Set 8 | ust-ilimsk
# Processing Record 25 of Set 8 | karratha
# Processing Record 26 of Set 8 | celestun
# Processing Record 27 of Set 8 | holland
# Processing Record 28 of Set 8 | pierre
# Processing Record 29 of Set 8 | mehamn
# Processing Record 30 of Set 8 | saint george
# Processing Record 31 of Set 8 | bima
# Processing Record 32 of Set 8 | rafai
# Processing Record 33 of Set 8 | majene
# Processing Record 34 of Set 8 | kundiawa
# Processing Record 35 of Set 8 | primorsko-akhtarsk
# Processing Record 36 of Set 8 | saint-francois
# Processing Record 37 of Set 8 | pitimbu
# Processing Record 38 of Set 8 | lasa
# Processing Record 39 of Set 8 | starodub
# Processing Record 40 of Set 8 | daru
# Processing Record 41 of Set 8 | adrar
# Processing Record 42 of Set 8 | kralendijk
# Processing Record 43 of Set 8 | san patricio
# Processing Record 44 of Set 8 | pafos
# Processing Record 45 of Set 8 | salinopolis
# Processing Record 46 of Set 8 | balkanabat
# Processing Record 47 of Set 8 | kargasok
# Processing Record 48 of Set 8 | tumannyy
# City not found. Skipping...
# Processing Record 49 of Set 8 | bathsheba
# Processing Record 50 of Set 8 | lillooet
# Processing Record 1 of Set 9 | almenevo
# City not found. Skipping...
# Processing Record 2 of Set 9 | tura
# Processing Record 3 of Set 9 | lebanon
# Processing Record 4 of Set 9 | goldsboro
# Processing Record 5 of Set 9 | kayerkan
# Processing Record 6 of Set 9 | kelso
# Processing Record 7 of Set 9 | yulara
# Processing Record 8 of Set 9 | safonovo
# Processing Record 9 of Set 9 | leh
# Processing Record 10 of Set 9 | huntington
# Processing Record 11 of Set 9 | khuzhir
# Processing Record 12 of Set 9 | kudahuvadhoo
# Processing Record 13 of Set 9 | mana
# Processing Record 14 of Set 9 | hofn
# Processing Record 15 of Set 9 | marsa matruh
# Processing Record 16 of Set 9 | toliary
# City not found. Skipping...
# Processing Record 17 of Set 9 | roald
# Processing Record 18 of Set 9 | hulan
# Processing Record 19 of Set 9 | college
# Processing Record 20 of Set 9 | kyabe
# Processing Record 21 of Set 9 | hambantota
# Processing Record 22 of Set 9 | vangaindrano
# Processing Record 23 of Set 9 | ariquemes
# Processing Record 24 of Set 9 | rovinj
# Processing Record 25 of Set 9 | launceston
# Processing Record 26 of Set 9 | shimoda
# Processing Record 27 of Set 9 | pinega
# Processing Record 28 of Set 9 | khonsa
# Processing Record 29 of Set 9 | chiredzi
# Processing Record 30 of Set 9 | mariinsk
# Processing Record 31 of Set 9 | klaksvik
# Processing Record 32 of Set 9 | pavullo nel frignano
# Processing Record 33 of Set 9 | tibiri
# Processing Record 34 of Set 9 | san cristobal
# Processing Record 35 of Set 9 | buluang
# Processing Record 36 of Set 9 | buala
# Processing Record 37 of Set 9 | the valley
# Processing Record 38 of Set 9 | tazovskiy
# Processing Record 39 of Set 9 | mayo
# Processing Record 40 of Set 9 | raudeberg
# Processing Record 41 of Set 9 | lakatoro
# Processing Record 42 of Set 9 | bilibino
# Processing Record 43 of Set 9 | xadani
# City not found. Skipping...
# Processing Record 44 of Set 9 | sainte-rose
# Processing Record 45 of Set 9 | singleton
# Processing Record 46 of Set 9 | siyabuswa
# Processing Record 47 of Set 9 | lesosibirsk
# Processing Record 48 of Set 9 | capreol
# Processing Record 49 of Set 9 | ossora
# Processing Record 50 of Set 9 | poum
# Processing Record 1 of Set 10 | uarini
# Processing Record 2 of Set 10 | zemio
# Processing Record 3 of Set 10 | sorvag
# City not found. Skipping...
# Processing Record 4 of Set 10 | agua verde
# Processing Record 5 of Set 10 | norman wells
# Processing Record 6 of Set 10 | amuntai
# Processing Record 7 of Set 10 | shimanovsk
# Processing Record 8 of Set 10 | narsaq
# Processing Record 9 of Set 10 | hirara
# Processing Record 10 of Set 10 | ribeira brava
# Processing Record 11 of Set 10 | marzuq
# Processing Record 12 of Set 10 | moose factory
# Processing Record 13 of Set 10 | yebaishou
# Processing Record 14 of Set 10 | shizunai
# Processing Record 15 of Set 10 | vaitape
# Processing Record 16 of Set 10 | oron
# Processing Record 17 of Set 10 | walvis bay
# Processing Record 18 of Set 10 | labuhan
# Processing Record 19 of Set 10 | santa rosa
# Processing Record 20 of Set 10 | djenne
# Processing Record 21 of Set 10 | chernyshevskiy
# Processing Record 22 of Set 10 | masallatah
# Processing Record 23 of Set 10 | beringovskiy
# Processing Record 24 of Set 10 | umzimvubu
# City not found. Skipping...
# Processing Record 25 of Set 10 | udachnyy
# Processing Record 26 of Set 10 | wad madani
# Processing Record 27 of Set 10 | kidal
# Processing Record 28 of Set 10 | chubbuck
# Processing Record 29 of Set 10 | robertson
# Processing Record 30 of Set 10 | hare bay
# Processing Record 31 of Set 10 | kloulklubed
# Processing Record 32 of Set 10 | sainte-suzanne
# Processing Record 33 of Set 10 | scarborough
# Processing Record 34 of Set 10 | nacala
# Processing Record 35 of Set 10 | salalah
# Processing Record 36 of Set 10 | saint-augustin
# Processing Record 37 of Set 10 | ahipara
# Processing Record 38 of Set 10 | villa carlos paz
# Processing Record 39 of Set 10 | sumen
# City not found. Skipping...
# Processing Record 40 of Set 10 | mount gambier
# Processing Record 41 of Set 10 | grand gaube
# Processing Record 42 of Set 10 | labuan
# Processing Record 43 of Set 10 | adeje
# Processing Record 44 of Set 10 | tarudant
# City not found. Skipping...
# Processing Record 45 of Set 10 | vila velha
# Processing Record 46 of Set 10 | alice springs
# Processing Record 47 of Set 10 | chaoyang
# Processing Record 48 of Set 10 | cabo san lucas
# Processing Record 49 of Set 10 | greensboro
# Processing Record 50 of Set 10 | gornyak
# Processing Record 1 of Set 11 | port-gentil
# Processing Record 2 of Set 11 | balabac
# Processing Record 3 of Set 11 | kiboga
# Processing Record 4 of Set 11 | tevaitoa
# Processing Record 5 of Set 11 | muli
# Processing Record 6 of Set 11 | zvishavane
# Processing Record 7 of Set 11 | honiara
# Processing Record 8 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 9 of Set 11 | alotau
# City not found. Skipping...
# Processing Record 10 of Set 11 | kenai
# Processing Record 11 of Set 11 | kruisfontein
# Processing Record 12 of Set 11 | sioux lookout
# Processing Record 13 of Set 11 | pangkalanbuun
# Processing Record 14 of Set 11 | alegrete
# Processing Record 15 of Set 11 | fukue
# Processing Record 16 of Set 11 | marovoay
# Processing Record 17 of Set 11 | basco
# Processing Record 18 of Set 11 | jiuquan
# Processing Record 19 of Set 11 | huanren
# Processing Record 20 of Set 11 | aleksandrovsk-sakhalinskiy
# Processing Record 21 of Set 11 | kazalinsk
# City not found. Skipping...
# Processing Record 22 of Set 11 | nador
# Processing Record 23 of Set 11 | virginia beach
# Processing Record 24 of Set 11 | lengshuijiang
# Processing Record 25 of Set 11 | cuamba
# Processing Record 26 of Set 11 | guiyang
# Processing Record 27 of Set 11 | beloha
# Processing Record 28 of Set 11 | bahir dar
# Processing Record 29 of Set 11 | parry sound
# Processing Record 30 of Set 11 | yaitepec
# City not found. Skipping...
# Processing Record 31 of Set 11 | beira
# Processing Record 32 of Set 11 | mounana
# Processing Record 33 of Set 11 | sovetskiy
# Processing Record 34 of Set 11 | wanning
# Processing Record 35 of Set 11 | parras
# City not found. Skipping...
# Processing Record 36 of Set 11 | gorontalo
# Processing Record 37 of Set 11 | sovetsk
# Processing Record 38 of Set 11 | bam
# Processing Record 39 of Set 11 | sechura
# Processing Record 40 of Set 11 | sabha
# Processing Record 41 of Set 11 | matadi
# Processing Record 42 of Set 11 | bojnurd
# Processing Record 43 of Set 11 | fairbanks
# Processing Record 44 of Set 11 | xining
# Processing Record 45 of Set 11 | alta floresta
# Processing Record 46 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 47 of Set 11 | jiayuguan
# Processing Record 48 of Set 11 | pinos
# Processing Record 49 of Set 11 | khandyga
# Processing Record 50 of Set 11 | kasongo-lunda
# Processing Record 1 of Set 12 | svetlogorsk
# Processing Record 2 of Set 12 | greencastle
# Processing Record 3 of Set 12 | samarai
# Processing Record 4 of Set 12 | ixtapa
# Processing Record 5 of Set 12 | belmonte
# Processing Record 6 of Set 12 | ritchie
# Processing Record 7 of Set 12 | wa
# City not found. Skipping...
# Processing Record 8 of Set 12 | flinders
# Processing Record 9 of Set 12 | chicama
# Processing Record 10 of Set 12 | oyama
# Processing Record 11 of Set 12 | formoso do araguaia
# City not found. Skipping...
# Processing Record 12 of Set 12 | lima
# Processing Record 13 of Set 12 | wulanhaote
# City not found. Skipping...
# Processing Record 14 of Set 12 | sinnamary
# Processing Record 15 of Set 12 | severo-yeniseyskiy
# Processing Record 16 of Set 12 | utiroa
# City not found. Skipping...
# Processing Record 17 of Set 12 | pisco
# Processing Record 18 of Set 12 | port hedland
# Processing Record 19 of Set 12 | likasi
# Processing Record 20 of Set 12 | sheridan
# Processing Record 21 of Set 12 | balagansk
# Processing Record 22 of Set 12 | yigou
# Processing Record 23 of Set 12 | sistranda
# Processing Record 24 of Set 12 | salinas
# Processing Record 25 of Set 12 | garissa
# Processing Record 26 of Set 12 | nocrich
# Processing Record 27 of Set 12 | olafsvik
# Processing Record 28 of Set 12 | karauzyak
# City not found. Skipping...
# Processing Record 29 of Set 12 | tinjah
# City not found. Skipping...
# Processing Record 30 of Set 12 | seoul
# Processing Record 31 of Set 12 | naco
# Processing Record 32 of Set 12 | kyra
# Processing Record 33 of Set 12 | atherton
# Processing Record 34 of Set 12 | pyapon
# Processing Record 35 of Set 12 | haibowan
# City not found. Skipping...
# Processing Record 36 of Set 12 | dalby
# Processing Record 37 of Set 12 | nongan
# Processing Record 38 of Set 12 | izazi
# Processing Record 39 of Set 12 | medea
# Processing Record 40 of Set 12 | pishin
# Processing Record 41 of Set 12 | santa lucia utatlan
# Processing Record 42 of Set 12 | prince rupert
# Processing Record 43 of Set 12 | nuuk
# Processing Record 44 of Set 12 | turukhansk
# Processing Record 45 of Set 12 | santa catarina de tepehuanes
# Processing Record 46 of Set 12 | araouane
# Processing Record 47 of Set 12 | bealanana
# Processing Record 48 of Set 12 | presidencia roque saenz pena
# Processing Record 49 of Set 12 | rungata
# City not found. Skipping...
# Processing Record 50 of Set 12 | pekan
# Processing Record 1 of Set 13 | ayolas
# Processing Record 2 of Set 13 | bafoulabe
# Processing Record 3 of Set 13 | maneadero
# Processing Record 4 of Set 13 | bondo
# Processing Record 5 of Set 13 | cockburn town
# Processing Record 6 of Set 13 | gaoua
# Processing Record 7 of Set 13 | dudinka
# Processing Record 8 of Set 13 | paamiut
# Processing Record 9 of Set 13 | jalu
# Processing Record 10 of Set 13 | langsa
# Processing Record 11 of Set 13 | dera bugti
# Processing Record 12 of Set 13 | plonsk
# Processing Record 13 of Set 13 | vani
# Processing Record 14 of Set 13 | port lincoln
# Processing Record 15 of Set 13 | byron bay
# Processing Record 16 of Set 13 | borogontsy
# Processing Record 17 of Set 13 | sahrak
# City not found. Skipping...
# Processing Record 18 of Set 13 | asau
# Processing Record 19 of Set 13 | reconquista
# Processing Record 20 of Set 13 | burnie
# Processing Record 21 of Set 13 | merritt island
# Processing Record 22 of Set 13 | koungou
# Processing Record 23 of Set 13 | broken hill
# Processing Record 24 of Set 13 | migori
# Processing Record 25 of Set 13 | rio gallegos
# Processing Record 26 of Set 13 | loubomo
# Processing Record 27 of Set 13 | luba
# Processing Record 28 of Set 13 | kamloops
# Processing Record 29 of Set 13 | porbandar
# Processing Record 30 of Set 13 | abu kamal
# Processing Record 31 of Set 13 | kismayo
# Processing Record 32 of Set 13 | wagar
# Processing Record 33 of Set 13 | louisbourg
# City not found. Skipping...
# Processing Record 34 of Set 13 | taltal
# Processing Record 35 of Set 13 | florianopolis
# Processing Record 36 of Set 13 | nsanje
# Processing Record 37 of Set 13 | huaiyin
# Processing Record 38 of Set 13 | birao
# Processing Record 39 of Set 13 | ocos
# Processing Record 40 of Set 13 | farah
# Processing Record 41 of Set 13 | monroe
# Processing Record 42 of Set 13 | neiafu
# Processing Record 43 of Set 13 | safwah
# City not found. Skipping...
# Processing Record 44 of Set 13 | athabasca
# Processing Record 45 of Set 13 | omboue
# Processing Record 46 of Set 13 | oussouye
# Processing Record 47 of Set 13 | arbazh
# Processing Record 48 of Set 13 | tanabe
# Processing Record 49 of Set 13 | irinjalakuda
# Processing Record 50 of Set 13 | nipawin
# Processing Record 1 of Set 14 | hovd
# Processing Record 2 of Set 14 | harper
# Processing Record 3 of Set 14 | pinawa
# Processing Record 4 of Set 14 | saint-raymond
# Processing Record 5 of Set 14 | voh
# Processing Record 6 of Set 14 | bocana de paiwas
# Processing Record 7 of Set 14 | charters towers
# Processing Record 8 of Set 14 | tacoronte
# Processing Record 9 of Set 14 | chifeng
# Processing Record 10 of Set 14 | half moon bay
# Processing Record 11 of Set 14 | halifax
# Processing Record 12 of Set 14 | najran
# Processing Record 13 of Set 14 | siirt
# Processing Record 14 of Set 14 | shingu
# Processing Record 15 of Set 14 | kumba
# Processing Record 16 of Set 14 | lodja
# Processing Record 17 of Set 14 | bossangoa
# Processing Record 18 of Set 14 | candido de abreu
# Processing Record 19 of Set 14 | savannah bight
# Processing Record 20 of Set 14 | buchanan
# Processing Record 21 of Set 14 | goderich
# Processing Record 22 of Set 14 | galveston
# Processing Record 23 of Set 14 | nyurba
# Processing Record 24 of Set 14 | otjimbingwe
# Processing Record 25 of Set 14 | algiers
# Processing Record 26 of Set 14 | jiaonan
# Processing Record 27 of Set 14 | sorland
# Processing Record 28 of Set 14 | aksha
# Processing Record 29 of Set 14 | palatka
# Processing Record 30 of Set 14 | kapiri mposhi
# Processing Record 31 of Set 14 | kushiro
# Processing Record 32 of Set 14 | jinxiang
# Processing Record 33 of Set 14 | vestmannaeyjar
# Processing Record 34 of Set 14 | rangia
# Processing Record 35 of Set 14 | malinovoye ozero
# Processing Record 36 of Set 14 | meadow lake
# Processing Record 37 of Set 14 | morro bay
# Processing Record 38 of Set 14 | richards bay
# Processing Record 39 of Set 14 | mingaora
# Processing Record 40 of Set 14 | christchurch
# Processing Record 41 of Set 14 | bilma
# Processing Record 42 of Set 14 | charleston
# Processing Record 43 of Set 14 | mairwa
# Processing Record 44 of Set 14 | pravia
# Processing Record 45 of Set 14 | normandin
# Processing Record 46 of Set 14 | antequera
# Processing Record 47 of Set 14 | vao
# Processing Record 48 of Set 14 | padang
# Processing Record 49 of Set 14 | mount isa
# Processing Record 50 of Set 14 | puerto carreno
# Processing Record 1 of Set 15 | yaksatovo
# Processing Record 2 of Set 15 | molina
# Processing Record 3 of Set 15 | pilar
# Processing Record 4 of Set 15 | jizan
# Processing Record 5 of Set 15 | ndouci
# City not found. Skipping...
# Processing Record 6 of Set 15 | amahai
# Processing Record 7 of Set 15 | meulaboh
# Processing Record 8 of Set 15 | mankono
# Processing Record 9 of Set 15 | ndele
# Processing Record 10 of Set 15 | muroto
# Processing Record 11 of Set 15 | jieshi
# Processing Record 12 of Set 15 | mingyue
# Processing Record 13 of Set 15 | vega de alatorre
# Processing Record 14 of Set 15 | kiama
# Processing Record 15 of Set 15 | iskateley
# Processing Record 16 of Set 15 | balimo
# City not found. Skipping...
# Processing Record 17 of Set 15 | galle
# Processing Record 18 of Set 15 | ikom
# Processing Record 19 of Set 15 | dhidhdhoo
# Processing Record 20 of Set 15 | banda aceh
# Processing Record 21 of Set 15 | andevoranto
# City not found. Skipping...
# Processing Record 22 of Set 15 | meyungs
# City not found. Skipping...
# Processing Record 23 of Set 15 | lardos
# Processing Record 24 of Set 15 | chilca
# Processing Record 25 of Set 15 | san-pedro
# Processing Record 26 of Set 15 | bolonchen
# City not found. Skipping...
# Processing Record 27 of Set 15 | vokhma
# Processing Record 28 of Set 15 | valenca
# Processing Record 29 of Set 15 | skibotn
# Processing Record 30 of Set 15 | hadishahr
# Processing Record 31 of Set 15 | kautokeino
# Processing Record 32 of Set 15 | maningrida
# Processing Record 33 of Set 15 | riyadh
# Processing Record 34 of Set 15 | mattru
# Processing Record 35 of Set 15 | orbetello
# Processing Record 36 of Set 15 | constitucion
# Processing Record 37 of Set 15 | alamos
# Processing Record 38 of Set 15 | biankouma
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame. 6.2.7
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0           Hithadhoo  -0.6000   73.0833     82.02        76         100
# 1            Hamilton  39.1834  -84.5333     30.20        40           1
# 2            Luderitz -26.6481   15.1594     76.10        47           0
# 3  Turinskaya Sloboda  57.6232   64.3858     34.50        97         100
# 4          Chokurdakh  70.6333  147.9167    -18.65        87          97
# 5         Bandarbeyla   9.4942   50.8122     76.93        78          15
# 6         Port Alfred -33.5906   26.8910     75.00        89          18
# 7              Viedma -40.8135  -62.9967     79.00        45           0
# 8         Henties Bay -22.1160   14.2845     64.99        87          16
# 9          North Bend  43.4065 -124.2243     44.60        93          90
#
#    Wind Speed Country Current Description
# 0       15.10      MV     overcast clouds
# 1        4.16      US           clear sky
# 2       29.57      NA           clear sky
# 3       10.76      RU          light rain
# 4        4.85      RU     overcast clouds
# 5       13.29      SO          few clouds
# 6        3.00      ZA          few clouds
# 7        1.01      AR           clear sky
# 8        1.99      NA          few clouds
# 9        3.44      US     overcast clouds

# %%
# Reorder the DataFrame
city_data_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 
                              'Current Description']]
city_data_df.head(10)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0           Hithadhoo      MV  -0.6000   73.0833     82.02        76
# 1            Hamilton      US  39.1834  -84.5333     30.20        40
# 2            Luderitz      NA -26.6481   15.1594     76.10        47
# 3  Turinskaya Sloboda      RU  57.6232   64.3858     34.50        97
# 4          Chokurdakh      RU  70.6333  147.9167    -18.65        87
# 5         Bandarbeyla      SO   9.4942   50.8122     76.93        78
# 6         Port Alfred      ZA -33.5906   26.8910     75.00        89
# 7              Viedma      AR -40.8135  -62.9967     79.00        45
# 8         Henties Bay      NA -22.1160   14.2845     64.99        87
# 9          North Bend      US  43.4065 -124.2243     44.60        93
#
#    Cloudiness  Wind Speed Current Description
# 0         100       15.10     overcast clouds
# 1           1        4.16           clear sky
# 2           0       29.57           clear sky
# 3         100       10.76          light rain
# 4          97        4.85     overcast clouds
# 5          15       13.29          few clouds
# 6          18        3.00          few clouds
# 7           0        1.01           clear sky
# 8          16        1.99          few clouds
# 9          90        3.44     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
