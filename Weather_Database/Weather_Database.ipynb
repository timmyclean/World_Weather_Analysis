# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.USe 'zip' function used to pair things
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 745

# %%
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.6.2.3
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
#print(url)

# %%
# Import the datetime module from the datetime library.
from datetime import datetime

# %%
city_weather
# Out:
# {'coord': {'lon': 115.6167, 'lat': -8.45},
#  'weather': [{'id': 801,
#    'main': 'Clouds',
#    'description': 'few clouds',
#    'icon': '02n'}],
#  'base': 'stations',
#  'main': {'temp': 77,
#   'feels_like': 87.26,
#   'temp_min': 77,
#   'temp_max': 77,
#   'pressure': 1008,
#   'humidity': 100},
#  'visibility': 10000,
#  'wind': {'speed': 2.3, 'deg': 50},
#  'clouds': {'all': 20},
#  'dt': 1612625621,
#  'sys': {'type': 1,
#   'id': 9333,
#   'country': 'ID',
#   'sunrise': 1612563515,
#   'sunset': 1612608279},
#  'timezone': 28800,
#  'id': 1641301,
#  'name': 'Amlapura',
#  'cod': 200}

# %%
# Create an empty list to hold the weather data.6.2.6
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1


# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1

# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current = city_weather["weather"][0]["description"]
        #6.2.5 
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description":city_current})
#         break

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
#         pass
#         break

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mar del plata
# Processing Record 2 of Set 1 | hithadhoo
# Processing Record 3 of Set 1 | lebu
# Processing Record 4 of Set 1 | bluff
# Processing Record 5 of Set 1 | lavrentiya
# Processing Record 6 of Set 1 | hualmay
# Processing Record 7 of Set 1 | san rafael del sur
# Processing Record 8 of Set 1 | te anau
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | severo-kurilsk
# Processing Record 11 of Set 1 | bambous virieux
# Processing Record 12 of Set 1 | cape town
# Processing Record 13 of Set 1 | bredasdorp
# Processing Record 14 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 15 of Set 1 | bengkulu
# Processing Record 16 of Set 1 | arraial do cabo
# Processing Record 17 of Set 1 | albany
# Processing Record 18 of Set 1 | grand-santi
# Processing Record 19 of Set 1 | mataura
# Processing Record 20 of Set 1 | rosehearty
# Processing Record 21 of Set 1 | san rafael
# Processing Record 22 of Set 1 | motril
# Processing Record 23 of Set 1 | oranjestad
# Processing Record 24 of Set 1 | new norfolk
# Processing Record 25 of Set 1 | yumen
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | tiznit
# Processing Record 28 of Set 1 | sitka
# Processing Record 29 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 30 of Set 1 | hermanus
# Processing Record 31 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 32 of Set 1 | pangody
# Processing Record 33 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 34 of Set 1 | carnarvon
# Processing Record 35 of Set 1 | thompson
# Processing Record 36 of Set 1 | vardo
# Processing Record 37 of Set 1 | rikitea
# Processing Record 38 of Set 1 | severnyy-kospashskiy
# Processing Record 39 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 40 of Set 1 | cabo san lucas
# Processing Record 41 of Set 1 | lugovoy
# Processing Record 42 of Set 1 | broken hill
# Processing Record 43 of Set 1 | kapaa
# Processing Record 44 of Set 1 | samusu
# City not found. Skipping...
# Processing Record 45 of Set 1 | mormugao
# Processing Record 46 of Set 1 | avarua
# Processing Record 47 of Set 1 | vostok
# Processing Record 48 of Set 1 | castro
# Processing Record 49 of Set 1 | vanimo
# Processing Record 50 of Set 1 | huarmey
# Processing Record 1 of Set 2 | mikhaylovka
# Processing Record 2 of Set 2 | sao filipe
# Processing Record 3 of Set 2 | saint-louis
# Processing Record 4 of Set 2 | yellowknife
# Processing Record 5 of Set 2 | kodiak
# Processing Record 6 of Set 2 | imbituba
# Processing Record 7 of Set 2 | jining
# Processing Record 8 of Set 2 | port blair
# Processing Record 9 of Set 2 | provideniya
# Processing Record 10 of Set 2 | college
# Processing Record 11 of Set 2 | busselton
# Processing Record 12 of Set 2 | punta arenas
# Processing Record 13 of Set 2 | east london
# Processing Record 14 of Set 2 | barbar
# City not found. Skipping...
# Processing Record 15 of Set 2 | roma
# Processing Record 16 of Set 2 | crotone
# Processing Record 17 of Set 2 | baboua
# City not found. Skipping...
# Processing Record 18 of Set 2 | la macarena
# Processing Record 19 of Set 2 | port macquarie
# Processing Record 20 of Set 2 | muzhi
# Processing Record 21 of Set 2 | tiksi
# Processing Record 22 of Set 2 | okhotsk
# Processing Record 23 of Set 2 | pevek
# Processing Record 24 of Set 2 | taraz
# Processing Record 25 of Set 2 | diego de almagro
# Processing Record 26 of Set 2 | kirkuk
# Processing Record 27 of Set 2 | port alfred
# Processing Record 28 of Set 2 | tynda
# Processing Record 29 of Set 2 | esperance
# Processing Record 30 of Set 2 | ayacucho
# Processing Record 31 of Set 2 | faya
# Processing Record 32 of Set 2 | hilo
# Processing Record 33 of Set 2 | upernavik
# Processing Record 34 of Set 2 | cidreira
# Processing Record 35 of Set 2 | olsztyn
# Processing Record 36 of Set 2 | butaritari
# Processing Record 37 of Set 2 | aklavik
# Processing Record 38 of Set 2 | san vicente
# Processing Record 39 of Set 2 | yulara
# Processing Record 40 of Set 2 | puerto del rosario
# Processing Record 41 of Set 2 | nova venecia
# Processing Record 42 of Set 2 | vaini
# Processing Record 43 of Set 2 | chautla
# City not found. Skipping...
# Processing Record 44 of Set 2 | umm lajj
# Processing Record 45 of Set 2 | broome
# Processing Record 46 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 2 | bandar-e torkaman
# City not found. Skipping...
# Processing Record 48 of Set 2 | flin flon
# Processing Record 49 of Set 2 | springfield
# Processing Record 50 of Set 2 | kupang
# Processing Record 1 of Set 3 | rimbey
# Processing Record 2 of Set 3 | gizo
# Processing Record 3 of Set 3 | ferrol
# Processing Record 4 of Set 3 | georgetown
# Processing Record 5 of Set 3 | khatanga
# Processing Record 6 of Set 3 | muros
# Processing Record 7 of Set 3 | talah
# City not found. Skipping...
# Processing Record 8 of Set 3 | westport
# Processing Record 9 of Set 3 | buin
# Processing Record 10 of Set 3 | saint-philippe
# Processing Record 11 of Set 3 | manokwari
# Processing Record 12 of Set 3 | marathon
# Processing Record 13 of Set 3 | dikson
# Processing Record 14 of Set 3 | kalas
# Processing Record 15 of Set 3 | ponta do sol
# Processing Record 16 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 17 of Set 3 | doka
# Processing Record 18 of Set 3 | iranshahr
# Processing Record 19 of Set 3 | camacha
# Processing Record 20 of Set 3 | cherskiy
# Processing Record 21 of Set 3 | port hedland
# Processing Record 22 of Set 3 | caravelas
# Processing Record 23 of Set 3 | ust-karsk
# Processing Record 24 of Set 3 | cornwall
# Processing Record 25 of Set 3 | bilma
# Processing Record 26 of Set 3 | comodoro rivadavia
# Processing Record 27 of Set 3 | hellvik
# Processing Record 28 of Set 3 | komsomolskiy
# Processing Record 29 of Set 3 | moose factory
# Processing Record 30 of Set 3 | tasiilaq
# Processing Record 31 of Set 3 | jamestown
# Processing Record 32 of Set 3 | ipora
# Processing Record 33 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 34 of Set 3 | chhapar
# Processing Record 35 of Set 3 | dinsor
# City not found. Skipping...
# Processing Record 36 of Set 3 | qasigiannguit
# Processing Record 37 of Set 3 | atuona
# Processing Record 38 of Set 3 | khawhai
# Processing Record 39 of Set 3 | raton
# Processing Record 40 of Set 3 | eshowe
# Processing Record 41 of Set 3 | yirol
# City not found. Skipping...
# Processing Record 42 of Set 3 | koumac
# Processing Record 43 of Set 3 | tupelo
# Processing Record 44 of Set 3 | sibolga
# Processing Record 45 of Set 3 | boa vista
# Processing Record 46 of Set 3 | constitucion
# Processing Record 47 of Set 3 | saurimo
# Processing Record 48 of Set 3 | victoria
# Processing Record 49 of Set 3 | ostrovnoy
# Processing Record 50 of Set 3 | raudeberg
# Processing Record 1 of Set 4 | kaeo
# Processing Record 2 of Set 4 | puerto ayora
# Processing Record 3 of Set 4 | lyubech
# Processing Record 4 of Set 4 | dhidhdhoo
# Processing Record 5 of Set 4 | zhanaozen
# Processing Record 6 of Set 4 | namwala
# Processing Record 7 of Set 4 | saint-augustin
# Processing Record 8 of Set 4 | necochea
# Processing Record 9 of Set 4 | romny
# Processing Record 10 of Set 4 | mahadday weyne
# City not found. Skipping...
# Processing Record 11 of Set 4 | namatanai
# Processing Record 12 of Set 4 | san estanislao
# Processing Record 13 of Set 4 | saskylakh
# Processing Record 14 of Set 4 | kerteh
# City not found. Skipping...
# Processing Record 15 of Set 4 | torbay
# Processing Record 16 of Set 4 | usinsk
# Processing Record 17 of Set 4 | ancud
# Processing Record 18 of Set 4 | onega
# Processing Record 19 of Set 4 | vila
# Processing Record 20 of Set 4 | cacoal
# Processing Record 21 of Set 4 | neiafu
# Processing Record 22 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 23 of Set 4 | iqaluit
# Processing Record 24 of Set 4 | hasaki
# Processing Record 25 of Set 4 | ballina
# Processing Record 26 of Set 4 | kudahuvadhoo
# Processing Record 27 of Set 4 | kavieng
# Processing Record 28 of Set 4 | alpena
# Processing Record 29 of Set 4 | port hardy
# Processing Record 30 of Set 4 | qaanaaq
# Processing Record 31 of Set 4 | codrington
# Processing Record 32 of Set 4 | port-cartier
# Processing Record 33 of Set 4 | katsuura
# Processing Record 34 of Set 4 | malia
# Processing Record 35 of Set 4 | tuatapere
# Processing Record 36 of Set 4 | rawson
# Processing Record 37 of Set 4 | jacksonville
# Processing Record 38 of Set 4 | nome
# Processing Record 39 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 40 of Set 4 | saldanha
# Processing Record 41 of Set 4 | orange
# Processing Record 42 of Set 4 | ribeira grande
# Processing Record 43 of Set 4 | coracao de jesus
# Processing Record 44 of Set 4 | hovd
# Processing Record 45 of Set 4 | idaho falls
# Processing Record 46 of Set 4 | kaitangata
# Processing Record 47 of Set 4 | avanigadda
# Processing Record 48 of Set 4 | port-gentil
# Processing Record 49 of Set 4 | gat
# Processing Record 50 of Set 4 | san cristobal
# Processing Record 1 of Set 5 | the valley
# Processing Record 2 of Set 5 | portland
# Processing Record 3 of Set 5 | bacolod
# Processing Record 4 of Set 5 | rawannawi
# City not found. Skipping...
# Processing Record 5 of Set 5 | peachland
# Processing Record 6 of Set 5 | palmer
# Processing Record 7 of Set 5 | los llanos de aridane
# Processing Record 8 of Set 5 | sorong
# Processing Record 9 of Set 5 | tommot
# Processing Record 10 of Set 5 | barrow
# Processing Record 11 of Set 5 | saryshagan
# City not found. Skipping...
# Processing Record 12 of Set 5 | pisco
# Processing Record 13 of Set 5 | hamilton
# Processing Record 14 of Set 5 | emerald
# Processing Record 15 of Set 5 | arco
# Processing Record 16 of Set 5 | norman wells
# Processing Record 17 of Set 5 | lorengau
# Processing Record 18 of Set 5 | tomari
# Processing Record 19 of Set 5 | touros
# Processing Record 20 of Set 5 | port elizabeth
# Processing Record 21 of Set 5 | kahului
# Processing Record 22 of Set 5 | abha
# Processing Record 23 of Set 5 | tateyama
# Processing Record 24 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 25 of Set 5 | magadan
# Processing Record 26 of Set 5 | cockburn town
# Processing Record 27 of Set 5 | cayenne
# Processing Record 28 of Set 5 | prince rupert
# Processing Record 29 of Set 5 | zelenoborskiy
# Processing Record 30 of Set 5 | pangnirtung
# Processing Record 31 of Set 5 | svetlogorsk
# Processing Record 32 of Set 5 | ilulissat
# Processing Record 33 of Set 5 | srednekolymsk
# Processing Record 34 of Set 5 | honningsvag
# Processing Record 35 of Set 5 | laguna
# Processing Record 36 of Set 5 | guerrero negro
# Processing Record 37 of Set 5 | talnakh
# Processing Record 38 of Set 5 | colares
# Processing Record 39 of Set 5 | pinyug
# Processing Record 40 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 41 of Set 5 | chuy
# Processing Record 42 of Set 5 | narovchat
# Processing Record 43 of Set 5 | dingle
# Processing Record 44 of Set 5 | ozernovskiy
# Processing Record 45 of Set 5 | pangkalanbuun
# Processing Record 46 of Set 5 | kaihua
# Processing Record 47 of Set 5 | berlevag
# Processing Record 48 of Set 5 | buariki
# City not found. Skipping...
# Processing Record 49 of Set 5 | myshkin
# Processing Record 50 of Set 5 | stekolnyy
# City not found. Skipping...
# Processing Record 1 of Set 6 | thinadhoo
# Processing Record 2 of Set 6 | rudnichnyy
# Processing Record 3 of Set 6 | bhanvad
# Processing Record 4 of Set 6 | mahebourg
# Processing Record 5 of Set 6 | dong hoi
# Processing Record 6 of Set 6 | airai
# Processing Record 7 of Set 6 | hohhot
# Processing Record 8 of Set 6 | kruisfontein
# Processing Record 9 of Set 6 | lompoc
# Processing Record 10 of Set 6 | sataua
# City not found. Skipping...
# Processing Record 11 of Set 6 | santa maria
# Processing Record 12 of Set 6 | chimbote
# Processing Record 13 of Set 6 | ayan
# Processing Record 14 of Set 6 | vila franca do campo
# Processing Record 15 of Set 6 | humberto de campos
# Processing Record 16 of Set 6 | seguela
# Processing Record 17 of Set 6 | la rioja
# Processing Record 18 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 6 | lahad datu
# Processing Record 20 of Set 6 | maua
# Processing Record 21 of Set 6 | fez
# Processing Record 22 of Set 6 | kande
# Processing Record 23 of Set 6 | kovdor
# Processing Record 24 of Set 6 | asau
# Processing Record 25 of Set 6 | gwanda
# Processing Record 26 of Set 6 | waverly
# Processing Record 27 of Set 6 | malanje
# Processing Record 28 of Set 6 | quiroga
# Processing Record 29 of Set 6 | alofi
# Processing Record 30 of Set 6 | goderich
# Processing Record 31 of Set 6 | ghoti
# Processing Record 32 of Set 6 | laya
# Processing Record 33 of Set 6 | sola
# Processing Record 34 of Set 6 | bosaso
# Processing Record 35 of Set 6 | bandarbeyla
# Processing Record 36 of Set 6 | santiago del estero
# Processing Record 37 of Set 6 | luena
# Processing Record 38 of Set 6 | kawhia
# Processing Record 39 of Set 6 | van
# Processing Record 40 of Set 6 | sterling
# Processing Record 41 of Set 6 | dhamtari
# Processing Record 42 of Set 6 | mezhdurechensk
# Processing Record 43 of Set 6 | praia da vitoria
# Processing Record 44 of Set 6 | lar gerd
# City not found. Skipping...
# Processing Record 45 of Set 6 | faanui
# Processing Record 46 of Set 6 | quang ngai
# Processing Record 47 of Set 6 | labuhan
# Processing Record 48 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 49 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 50 of Set 6 | turukhansk
# Processing Record 1 of Set 7 | souillac
# Processing Record 2 of Set 7 | hay river
# Processing Record 3 of Set 7 | sonoita
# Processing Record 4 of Set 7 | toamasina
# Processing Record 5 of Set 7 | san policarpo
# Processing Record 6 of Set 7 | geraldton
# Processing Record 7 of Set 7 | multan
# Processing Record 8 of Set 7 | waipawa
# Processing Record 9 of Set 7 | marevo
# Processing Record 10 of Set 7 | great falls
# Processing Record 11 of Set 7 | san isidro
# Processing Record 12 of Set 7 | mehamn
# Processing Record 13 of Set 7 | gushikawa
# Processing Record 14 of Set 7 | tsihombe
# City not found. Skipping...
# Processing Record 15 of Set 7 | bethel
# Processing Record 16 of Set 7 | longyan
# Processing Record 17 of Set 7 | muli
# Processing Record 18 of Set 7 | jega
# Processing Record 19 of Set 7 | bargal
# City not found. Skipping...
# Processing Record 20 of Set 7 | longlac
# City not found. Skipping...
# Processing Record 21 of Set 7 | smolyaninovo
# Processing Record 22 of Set 7 | buala
# Processing Record 23 of Set 7 | paoua
# Processing Record 24 of Set 7 | san juan
# Processing Record 25 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 26 of Set 7 | karatuzskoye
# Processing Record 27 of Set 7 | shache
# Processing Record 28 of Set 7 | portree
# Processing Record 29 of Set 7 | san patricio
# Processing Record 30 of Set 7 | la ronge
# Processing Record 31 of Set 7 | fevralsk
# City not found. Skipping...
# Processing Record 32 of Set 7 | fortuna
# Processing Record 33 of Set 7 | vondrozo
# Processing Record 34 of Set 7 | naberera
# Processing Record 35 of Set 7 | drobeta-turnu severin
# Processing Record 36 of Set 7 | joao pinheiro
# Processing Record 37 of Set 7 | shakhtinsk
# Processing Record 38 of Set 7 | chokurdakh
# Processing Record 39 of Set 7 | nanortalik
# Processing Record 40 of Set 7 | durusu
# Processing Record 41 of Set 7 | kuusamo
# Processing Record 42 of Set 7 | bonavista
# Processing Record 43 of Set 7 | igrim
# Processing Record 44 of Set 7 | narsaq
# Processing Record 45 of Set 7 | pimentel
# Processing Record 46 of Set 7 | mayumba
# Processing Record 47 of Set 7 | jishou
# Processing Record 48 of Set 7 | eureka
# Processing Record 49 of Set 7 | vestmannaeyjar
# Processing Record 50 of Set 7 | irbit
# Processing Record 1 of Set 8 | lagoa
# Processing Record 2 of Set 8 | mayor pablo lagerenza
# Processing Record 3 of Set 8 | seymchan
# Processing Record 4 of Set 8 | rio grande
# Processing Record 5 of Set 8 | marawi
# Processing Record 6 of Set 8 | batsfjord
# Processing Record 7 of Set 8 | russell
# Processing Record 8 of Set 8 | sukhumi
# Processing Record 9 of Set 8 | lima
# Processing Record 10 of Set 8 | jijiga
# Processing Record 11 of Set 8 | bolungarvik
# City not found. Skipping...
# Processing Record 12 of Set 8 | sorland
# Processing Record 13 of Set 8 | peniche
# Processing Record 14 of Set 8 | harper
# Processing Record 15 of Set 8 | kivsharivka
# Processing Record 16 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 17 of Set 8 | fairbanks
# Processing Record 18 of Set 8 | camacupa
# Processing Record 19 of Set 8 | saryozek
# Processing Record 20 of Set 8 | lebanon
# Processing Record 21 of Set 8 | cervo
# Processing Record 22 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 23 of Set 8 | haines junction
# Processing Record 24 of Set 8 | havre-saint-pierre
# Processing Record 25 of Set 8 | mukhen
# Processing Record 26 of Set 8 | derzhavinsk
# Processing Record 27 of Set 8 | ranau
# Processing Record 28 of Set 8 | preobrazheniye
# Processing Record 29 of Set 8 | aparecida do taboado
# Processing Record 30 of Set 8 | yar-sale
# Processing Record 31 of Set 8 | soligalich
# Processing Record 32 of Set 8 | karkaralinsk
# City not found. Skipping...
# Processing Record 33 of Set 8 | lodja
# Processing Record 34 of Set 8 | nikolskoye
# Processing Record 35 of Set 8 | karpuninskiy
# City not found. Skipping...
# Processing Record 36 of Set 8 | saint-michel-des-saints
# Processing Record 37 of Set 8 | hove
# Processing Record 38 of Set 8 | vao
# Processing Record 39 of Set 8 | arrifes
# Processing Record 40 of Set 8 | beloha
# Processing Record 41 of Set 8 | piacabucu
# Processing Record 42 of Set 8 | progreso
# Processing Record 43 of Set 8 | kualakapuas
# Processing Record 44 of Set 8 | nador
# Processing Record 45 of Set 8 | saint george
# Processing Record 46 of Set 8 | jurm
# Processing Record 47 of Set 8 | alice springs
# Processing Record 48 of Set 8 | beringovskiy
# Processing Record 49 of Set 8 | luwuk
# Processing Record 50 of Set 8 | sisimiut
# Processing Record 1 of Set 9 | wattegama
# Processing Record 2 of Set 9 | tursunzoda
# Processing Record 3 of Set 9 | adrar
# Processing Record 4 of Set 9 | marzuq
# Processing Record 5 of Set 9 | numaligarh
# Processing Record 6 of Set 9 | leningradskiy
# Processing Record 7 of Set 9 | klaksvik
# Processing Record 8 of Set 9 | marseille
# Processing Record 9 of Set 9 | baghdad
# Processing Record 10 of Set 9 | port augusta
# Processing Record 11 of Set 9 | turbat
# Processing Record 12 of Set 9 | hervey bay
# Processing Record 13 of Set 9 | galgani
# City not found. Skipping...
# Processing Record 14 of Set 9 | buchanan
# Processing Record 15 of Set 9 | yatou
# Processing Record 16 of Set 9 | pacific grove
# Processing Record 17 of Set 9 | tuktoyaktuk
# Processing Record 18 of Set 9 | umzimvubu
# City not found. Skipping...
# Processing Record 19 of Set 9 | meulaboh
# Processing Record 20 of Set 9 | ribeira do pombal
# Processing Record 21 of Set 9 | isangel
# Processing Record 22 of Set 9 | camopi
# Processing Record 23 of Set 9 | port lincoln
# Processing Record 24 of Set 9 | salinas
# Processing Record 25 of Set 9 | jumla
# Processing Record 26 of Set 9 | ngukurr
# City not found. Skipping...
# Processing Record 27 of Set 9 | kabanjahe
# Processing Record 28 of Set 9 | beroroha
# Processing Record 29 of Set 9 | margate
# Processing Record 30 of Set 9 | saint-donat-de-montcalm
# Processing Record 31 of Set 9 | panixtlahuaca
# City not found. Skipping...
# Processing Record 32 of Set 9 | guane
# Processing Record 33 of Set 9 | xining
# Processing Record 34 of Set 9 | agirish
# Processing Record 35 of Set 9 | cacheu
# Processing Record 36 of Set 9 | santa cruz
# Processing Record 37 of Set 9 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 9 | senno
# Processing Record 39 of Set 9 | longyearbyen
# Processing Record 40 of Set 9 | amderma
# City not found. Skipping...
# Processing Record 41 of Set 9 | yugo-kamskiy
# Processing Record 42 of Set 9 | hambantota
# Processing Record 43 of Set 9 | sao lourenco do sul
# Processing Record 44 of Set 9 | kogon
# Processing Record 45 of Set 9 | young
# Processing Record 46 of Set 9 | kourou
# Processing Record 47 of Set 9 | riyadh
# Processing Record 48 of Set 9 | boyolangu
# Processing Record 49 of Set 9 | merauke
# Processing Record 50 of Set 9 | saint-pierre
# Processing Record 1 of Set 10 | snezhnogorsk
# Processing Record 2 of Set 10 | aracaju
# Processing Record 3 of Set 10 | okha
# Processing Record 4 of Set 10 | naze
# Processing Record 5 of Set 10 | wawa
# Processing Record 6 of Set 10 | gagra
# Processing Record 7 of Set 10 | sabzevar
# Processing Record 8 of Set 10 | uppsala
# Processing Record 9 of Set 10 | itaituba
# Processing Record 10 of Set 10 | clyde river
# Processing Record 11 of Set 10 | burica
# City not found. Skipping...
# Processing Record 12 of Set 10 | bowen
# Processing Record 13 of Set 10 | jalu
# Processing Record 14 of Set 10 | melo
# Processing Record 15 of Set 10 | mae sai
# Processing Record 16 of Set 10 | neufahrn
# Processing Record 17 of Set 10 | luanda
# Processing Record 18 of Set 10 | general pico
# Processing Record 19 of Set 10 | kortkeros
# Processing Record 20 of Set 10 | marienburg
# Processing Record 21 of Set 10 | freeport
# Processing Record 22 of Set 10 | salalah
# Processing Record 23 of Set 10 | summerland
# Processing Record 24 of Set 10 | sangar
# Processing Record 25 of Set 10 | coihaique
# Processing Record 26 of Set 10 | sal rei
# Processing Record 27 of Set 10 | kumertau
# Processing Record 28 of Set 10 | kalat
# Processing Record 29 of Set 10 | verkh-usugli
# Processing Record 30 of Set 10 | noumea
# Processing Record 31 of Set 10 | northam
# Processing Record 32 of Set 10 | vila velha
# Processing Record 33 of Set 10 | fort-shevchenko
# Processing Record 34 of Set 10 | san quintin
# Processing Record 35 of Set 10 | belaya gora
# Processing Record 36 of Set 10 | kanniyakumari
# Processing Record 37 of Set 10 | lasa
# Processing Record 38 of Set 10 | chernyshevskiy
# Processing Record 39 of Set 10 | bantry
# Processing Record 40 of Set 10 | soyo
# Processing Record 41 of Set 10 | skibbereen
# Processing Record 42 of Set 10 | lata
# Processing Record 43 of Set 10 | balagansk
# Processing Record 44 of Set 10 | natchitoches
# Processing Record 45 of Set 10 | collie
# Processing Record 46 of Set 10 | falkensee
# Processing Record 47 of Set 10 | burnie
# Processing Record 48 of Set 10 | kununurra
# Processing Record 49 of Set 10 | edson
# Processing Record 50 of Set 10 | coahuayana
# Processing Record 1 of Set 11 | nabire
# Processing Record 2 of Set 11 | tucurui
# Processing Record 3 of Set 11 | griffith
# Processing Record 4 of Set 11 | sept-iles
# Processing Record 5 of Set 11 | susehri
# Processing Record 6 of Set 11 | coquimbo
# Processing Record 7 of Set 11 | kloulklubed
# Processing Record 8 of Set 11 | san-pedro
# Processing Record 9 of Set 11 | sayyan
# Processing Record 10 of Set 11 | khudumelapye
# Processing Record 11 of Set 11 | cerritos
# Processing Record 12 of Set 11 | bubaque
# Processing Record 13 of Set 11 | ilinskoye-khovanskoye
# Processing Record 14 of Set 11 | carlagan
# Processing Record 15 of Set 11 | bakel
# Processing Record 16 of Set 11 | sur
# Processing Record 17 of Set 11 | beyneu
# Processing Record 18 of Set 11 | litovko
# Processing Record 19 of Set 11 | west bay
# Processing Record 20 of Set 11 | vuktyl
# Processing Record 21 of Set 11 | acarau
# Processing Record 22 of Set 11 | mwinilunga
# Processing Record 23 of Set 11 | guayama
# Processing Record 24 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 25 of Set 11 | riverton
# Processing Record 26 of Set 11 | hami
# Processing Record 27 of Set 11 | valdivia
# Processing Record 28 of Set 11 | nantucket
# Processing Record 29 of Set 11 | sakakah
# Processing Record 30 of Set 11 | fukue
# Processing Record 31 of Set 11 | kouango
# Processing Record 32 of Set 11 | nizhneyansk
# City not found. Skipping...
# Processing Record 33 of Set 11 | ocos
# Processing Record 34 of Set 11 | huicungo
# Processing Record 35 of Set 11 | lawrence
# Processing Record 36 of Set 11 | mafeteng
# Processing Record 37 of Set 11 | devils lake
# Processing Record 38 of Set 11 | giyon
# Processing Record 39 of Set 11 | medicine hat
# Processing Record 40 of Set 11 | antofagasta
# Processing Record 41 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 42 of Set 11 | juxian
# City not found. Skipping...
# Processing Record 43 of Set 11 | linjiang
# Processing Record 44 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 11 | solntsevo
# Processing Record 46 of Set 11 | saint anthony
# Processing Record 47 of Set 11 | pilibanga
# Processing Record 48 of Set 11 | kalia
# Processing Record 49 of Set 11 | sisophon
# Processing Record 50 of Set 11 | solvychegodsk
# Processing Record 1 of Set 12 | shu
# Processing Record 2 of Set 12 | ponta delgada
# Processing Record 3 of Set 12 | north bend
# Processing Record 4 of Set 12 | vengerovo
# Processing Record 5 of Set 12 | ajdabiya
# Processing Record 6 of Set 12 | alexandria
# Processing Record 7 of Set 12 | taksimo
# Processing Record 8 of Set 12 | porto velho
# Processing Record 9 of Set 12 | medea
# Processing Record 10 of Set 12 | enshi
# Processing Record 11 of Set 12 | zurrieq
# Processing Record 12 of Set 12 | betsiamites
# Processing Record 13 of Set 12 | walvis bay
# Processing Record 14 of Set 12 | evensk
# Processing Record 15 of Set 12 | watsa
# Processing Record 16 of Set 12 | solwezi
# Processing Record 17 of Set 12 | antalaha
# Processing Record 18 of Set 12 | hebertville
# City not found. Skipping...
# Processing Record 19 of Set 12 | nobres
# Processing Record 20 of Set 12 | egvekinot
# Processing Record 21 of Set 12 | cam pha
# City not found. Skipping...
# Processing Record 22 of Set 12 | benicarlo
# Processing Record 23 of Set 12 | sicuani
# Processing Record 24 of Set 12 | tunduru
# City not found. Skipping...
# Processing Record 25 of Set 12 | lamu
# Processing Record 26 of Set 12 | shakawe
# Processing Record 27 of Set 12 | mizdah
# Processing Record 28 of Set 12 | bathsheba
# Processing Record 29 of Set 12 | fayaoue
# Processing Record 30 of Set 12 | stutterheim
# Processing Record 31 of Set 12 | phuket
# Processing Record 32 of Set 12 | lufilufi
# Processing Record 33 of Set 12 | olafsvik
# Processing Record 34 of Set 12 | paso de los toros
# Processing Record 35 of Set 12 | louisbourg
# City not found. Skipping...
# Processing Record 36 of Set 12 | ridgecrest
# Processing Record 37 of Set 12 | teeli
# Processing Record 38 of Set 12 | fare
# Processing Record 39 of Set 12 | dourados
# Processing Record 40 of Set 12 | shirpur
# Processing Record 41 of Set 12 | porosozero
# Processing Record 42 of Set 12 | kapit
# Processing Record 43 of Set 12 | zhigansk
# Processing Record 44 of Set 12 | waddan
# Processing Record 45 of Set 12 | alyangula
# Processing Record 46 of Set 12 | agadez
# Processing Record 47 of Set 12 | quelimane
# Processing Record 48 of Set 12 | torrington
# Processing Record 49 of Set 12 | tarakan
# Processing Record 50 of Set 12 | winneba
# Processing Record 1 of Set 13 | cayhagan
# Processing Record 2 of Set 13 | nouadhibou
# Processing Record 3 of Set 13 | tilichiki
# Processing Record 4 of Set 13 | lakes entrance
# Processing Record 5 of Set 13 | scarborough
# Processing Record 6 of Set 13 | kavaratti
# Processing Record 7 of Set 13 | beira
# Processing Record 8 of Set 13 | kazerun
# Processing Record 9 of Set 13 | aquiraz
# Processing Record 10 of Set 13 | torbat-e jam
# Processing Record 11 of Set 13 | sin-le-noble
# Processing Record 12 of Set 13 | anuradhapura
# Processing Record 13 of Set 13 | maxixe
# Processing Record 14 of Set 13 | torrevieja
# Processing Record 15 of Set 13 | challapata
# Processing Record 16 of Set 13 | tillabery
# City not found. Skipping...
# Processing Record 17 of Set 13 | lengshuijiang
# Processing Record 18 of Set 13 | aripuana
# Processing Record 19 of Set 13 | ambon
# Processing Record 20 of Set 13 | uruzgan
# Processing Record 21 of Set 13 | trairi
# Processing Record 22 of Set 13 | atar
# Processing Record 23 of Set 13 | farafangana
# Processing Record 24 of Set 13 | gobabis
# Processing Record 25 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 26 of Set 13 | ushtobe
# Processing Record 27 of Set 13 | grindavik
# Processing Record 28 of Set 13 | campbell river
# Processing Record 29 of Set 13 | benguela
# Processing Record 30 of Set 13 | kingsport
# Processing Record 31 of Set 13 | vossevangen
# Processing Record 32 of Set 13 | verrettes
# Processing Record 33 of Set 13 | draguignan
# Processing Record 34 of Set 13 | pecos
# Processing Record 35 of Set 13 | bodden town
# Processing Record 36 of Set 13 | matara
# Processing Record 37 of Set 13 | chichicastenango
# Processing Record 38 of Set 13 | bata
# Processing Record 39 of Set 13 | urumqi
# Processing Record 40 of Set 13 | tiarei
# Processing Record 41 of Set 13 | boddam
# Processing Record 42 of Set 13 | qaqortoq
# Processing Record 43 of Set 13 | lokosovo
# Processing Record 44 of Set 13 | acapulco
# Processing Record 45 of Set 13 | edd
# Processing Record 46 of Set 13 | rabo de peixe
# Processing Record 47 of Set 13 | ardesen
# Processing Record 48 of Set 13 | kazalinsk
# City not found. Skipping...
# Processing Record 49 of Set 13 | rivera
# Processing Record 50 of Set 13 | zolotinka
# City not found. Skipping...
# Processing Record 1 of Set 14 | jurmala
# Processing Record 2 of Set 14 | aswan
# Processing Record 3 of Set 14 | baillif
# Processing Record 4 of Set 14 | mahajanga
# Processing Record 5 of Set 14 | pakxe
# Processing Record 6 of Set 14 | quatre cocos
# Processing Record 7 of Set 14 | rundu
# Processing Record 8 of Set 14 | ca mau
# Processing Record 9 of Set 14 | itacare
# Processing Record 10 of Set 14 | mbalmayo
# Processing Record 11 of Set 14 | paragominas
# Processing Record 12 of Set 14 | murud
# Processing Record 13 of Set 14 | poronaysk
# Processing Record 14 of Set 14 | prokhorovka
# Processing Record 15 of Set 14 | uyovu
# Processing Record 16 of Set 14 | rungata
# City not found. Skipping...
# Processing Record 17 of Set 14 | la carolina
# Processing Record 18 of Set 14 | namibe
# Processing Record 19 of Set 14 | ruatoria
# City not found. Skipping...
# Processing Record 20 of Set 14 | natal
# Processing Record 21 of Set 14 | rocha
# Processing Record 22 of Set 14 | manono
# Processing Record 23 of Set 14 | istmina
# Processing Record 24 of Set 14 | havelock
# Processing Record 25 of Set 14 | kuytun
# Processing Record 26 of Set 14 | najran
# Processing Record 27 of Set 14 | zemio
# Processing Record 28 of Set 14 | lubango
# Processing Record 29 of Set 14 | champerico
# Processing Record 30 of Set 14 | dzilam gonzalez
# Processing Record 31 of Set 14 | ampanihy
# Processing Record 32 of Set 14 | lardos
# Processing Record 33 of Set 14 | pechenga
# Processing Record 34 of Set 14 | morehead
# Processing Record 35 of Set 14 | kattivakkam
# Processing Record 36 of Set 14 | fort nelson
# Processing Record 37 of Set 14 | marshall
# Processing Record 38 of Set 14 | luzhou
# Processing Record 39 of Set 14 | dalby
# Processing Record 40 of Set 14 | nenjiang
# Processing Record 41 of Set 14 | puyo
# Processing Record 42 of Set 14 | columbia
# Processing Record 43 of Set 14 | banda aceh
# Processing Record 44 of Set 14 | stornoway
# Processing Record 45 of Set 14 | olinda
# Processing Record 46 of Set 14 | dharchula
# Processing Record 47 of Set 14 | senanga
# Processing Record 48 of Set 14 | bikaner
# Processing Record 49 of Set 14 | khandyga
# Processing Record 50 of Set 14 | martapura
# Processing Record 1 of Set 15 | bilibino
# Processing Record 2 of Set 15 | berwick
# Processing Record 3 of Set 15 | pineville
# Processing Record 4 of Set 15 | salinopolis
# Processing Record 5 of Set 15 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 6 of Set 15 | turan
# Processing Record 7 of Set 15 | inirida
# Processing Record 8 of Set 15 | gerash
# Processing Record 9 of Set 15 | surt
# Processing Record 10 of Set 15 | mamburao
# Processing Record 11 of Set 15 | bitung
# Processing Record 12 of Set 15 | cao bang
# Processing Record 13 of Set 15 | bessonovka
# Processing Record 14 of Set 15 | kondinskoye
# Processing Record 15 of Set 15 | makakilo city
# Processing Record 16 of Set 15 | warrington
# Processing Record 17 of Set 15 | asfi
# Processing Record 18 of Set 15 | doha
# Processing Record 19 of Set 15 | le port
# Processing Record 20 of Set 15 | tonneins
# Processing Record 21 of Set 15 | zhuozhou
# City not found. Skipping...
# Processing Record 22 of Set 15 | belyy yar
# Processing Record 23 of Set 15 | husavik
# Processing Record 24 of Set 15 | north platte
# Processing Record 25 of Set 15 | maghama
# City not found. Skipping...
# Processing Record 26 of Set 15 | maceio
# Processing Record 27 of Set 15 | mendahara
# City not found. Skipping...
# Processing Record 28 of Set 15 | impfondo
# Processing Record 29 of Set 15 | kuznechnoye
# Processing Record 30 of Set 15 | puerto escondido
# Processing Record 31 of Set 15 | gejiu
# Processing Record 32 of Set 15 | oskarshamn
# Processing Record 33 of Set 15 | sorbhog
# Processing Record 34 of Set 15 | nandgaon
# Processing Record 35 of Set 15 | maniitsoq
# Processing Record 36 of Set 15 | mogadishu
# Processing Record 37 of Set 15 | karaton
# Processing Record 38 of Set 15 | nhulunbuy
# Processing Record 39 of Set 15 | port keats
# Processing Record 40 of Set 15 | plettenberg bay
# Processing Record 41 of Set 15 | pochutla
# Processing Record 42 of Set 15 | kurilsk
# Processing Record 43 of Set 15 | pombas
# Processing Record 44 of Set 15 | sarangpur
# Processing Record 45 of Set 15 | karangasem
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
city_data
# Out:
# [{'City': 'Mar Del Plata',
#   'Lat': -38.0023,
#   'Lng': -57.5575,
#   'Max Temp': 73,
#   'Humidity': 68,
#   'Cloudiness': 75,
#   'Wind Speed': 13.8,
#   'Country': 'AR',
#   'Current Description': 'broken clouds'},
#  {'City': 'Hithadhoo',
#   'Lat': -0.6,
#   'Lng': 73.0833,
#   'Max Temp': 81.99,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 14.25,
#   'Country': 'MV',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lebu',
#   'Lat': -37.6167,
#   'Lng': -73.65,
#   'Max Temp': 62.74,
#   'Humidity': 77,
#   'Cloudiness': 92,
#   'Wind Speed': 6.29,
#   'Country': 'CL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bluff',
#   'Lat': -46.6,
#   'Lng': 168.3333,
#   'Max Temp': 54.27,
#   'Humidity': 86,
#   'Cloudiness': 9,
#   'Wind Speed': 1.45,
#   'Country': 'NZ',
#   'Current Description': 'clear sky'},
#  {'City': 'Lavrentiya',
#   'Lat': 65.5833,
#   'Lng': -171,
#   'Max Temp': -1.66,
#   'Humidity': 86,
#   'Cloudiness': 96,
#   'Wind Speed': 6.89,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hualmay',
#   'Lat': -11.0964,
#   'Lng': -77.6139,
#   'Max Temp': 74.75,
#   'Humidity': 66,
#   'Cloudiness': 94,
#   'Wind Speed': 8.43,
#   'Country': 'PE',
#   'Current Description': 'overcast clouds'},
#  {'City': 'San Rafael Del Sur',
#   'Lat': 11.8485,
#   'Lng': -86.4384,
#   'Max Temp': 82.4,
#   'Humidity': 65,
#   'Cloudiness': 20,
#   'Wind Speed': 6.91,
#   'Country': 'NI',
#   'Current Description': 'few clouds'},
#  {'City': 'Te Anau',
#   'Lat': -45.4167,
#   'Lng': 167.7167,
#   'Max Temp': 52.79,
#   'Humidity': 85,
#   'Cloudiness': 24,
#   'Wind Speed': 0.94,
#   'Country': 'NZ',
#   'Current Description': 'few clouds'},
#  {'City': 'Ushuaia',
#   'Lat': -54.8,
#   'Lng': -68.3,
#   'Max Temp': 51.8,
#   'Humidity': 50,
#   'Cloudiness': 40,
#   'Wind Speed': 19.57,
#   'Country': 'AR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Severo-Kurilsk',
#   'Lat': 50.6789,
#   'Lng': 156.125,
#   'Max Temp': 19.58,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 16.98,
#   'Country': 'RU',
#   'Current Description': 'light snow'},
#  {'City': 'Bambous Virieux',
#   'Lat': -20.3428,
#   'Lng': 57.7575,
#   'Max Temp': 80.6,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'MU',
#   'Current Description': 'few clouds'},
#  {'City': 'Cape Town',
#   'Lat': -33.9258,
#   'Lng': 18.4232,
#   'Max Temp': 79,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 18.41,
#   'Country': 'ZA',
#   'Current Description': 'clear sky'},
#  {'City': 'Bredasdorp',
#   'Lat': -34.5322,
#   'Lng': 20.0403,
#   'Max Temp': 78.8,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Country': 'ZA',
#   'Current Description': 'clear sky'},
#  {'City': 'Bengkulu',
#   'Lat': -3.8004,
#   'Lng': 102.2655,
#   'Max Temp': 76.86,
#   'Humidity': 85,
#   'Cloudiness': 78,
#   'Wind Speed': 6.55,
#   'Country': 'ID',
#   'Current Description': 'broken clouds'},
#  {'City': 'Arraial Do Cabo',
#   'Lat': -22.9661,
#   'Lng': -42.0278,
#   'Max Temp': 75.2,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'BR',
#   'Current Description': 'broken clouds'},
#  {'City': 'Albany',
#   'Lat': 42.6001,
#   'Lng': -73.9662,
#   'Max Temp': 35.01,
#   'Humidity': 37,
#   'Cloudiness': 76,
#   'Wind Speed': 4,
#   'Country': 'US',
#   'Current Description': 'light snow'},
#  {'City': 'Grand-Santi',
#   'Lat': 4.25,
#   'Lng': -54.3833,
#   'Max Temp': 80.91,
#   'Humidity': 88,
#   'Cloudiness': 87,
#   'Wind Speed': 4.9,
#   'Country': 'GF',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mataura',
#   'Lat': -46.1927,
#   'Lng': 168.8643,
#   'Max Temp': 49.21,
#   'Humidity': 94,
#   'Cloudiness': 3,
#   'Wind Speed': 1.16,
#   'Country': 'NZ',
#   'Current Description': 'clear sky'},
#  {'City': 'Rosehearty',
#   'Lat': 57.697,
#   'Lng': -2.1132,
#   'Max Temp': 33.01,
#   'Humidity': 66,
#   'Cloudiness': 100,
#   'Wind Speed': 15.99,
#   'Country': 'GB',
#   'Current Description': 'snow'},
#  {'City': 'San Rafael',
#   'Lat': -34.6177,
#   'Lng': -68.3301,
#   'Max Temp': 87.55,
#   'Humidity': 25,
#   'Cloudiness': 0,
#   'Wind Speed': 14.32,
#   'Country': 'AR',
#   'Current Description': 'clear sky'},
#  {'City': 'Motril',
#   'Lat': 36.7507,
#   'Lng': -3.5179,
#   'Max Temp': 59,
#   'Humidity': 82,
#   'Cloudiness': 16,
#   'Wind Speed': 3,
#   'Country': 'ES',
#   'Current Description': 'few clouds'},
#  {'City': 'Oranjestad',
#   'Lat': 12.524,
#   'Lng': -70.027,
#   'Max Temp': 84.2,
#   'Humidity': 61,
#   'Cloudiness': 20,
#   'Wind Speed': 23.02,
#   'Country': 'AW',
#   'Current Description': 'few clouds'},
#  {'City': 'New Norfolk',
#   'Lat': -42.7826,
#   'Lng': 147.0587,
#   'Max Temp': 57.2,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Yumen',
#   'Lat': 40.2833,
#   'Lng': 97.2,
#   'Max Temp': 27.95,
#   'Humidity': 74,
#   'Cloudiness': 54,
#   'Wind Speed': 3.18,
#   'Country': 'CN',
#   'Current Description': 'broken clouds'},
#  {'City': 'Hobart',
#   'Lat': -42.8794,
#   'Lng': 147.3294,
#   'Max Temp': 57.2,
#   'Humidity': 88,
#   'Cloudiness': 90,
#   'Wind Speed': 5.75,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tiznit',
#   'Lat': 29.5833,
#   'Lng': -9.5,
#   'Max Temp': 52.75,
#   'Humidity': 65,
#   'Cloudiness': 96,
#   'Wind Speed': 15.21,
#   'Country': 'MA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sitka',
#   'Lat': 57.0531,
#   'Lng': -135.33,
#   'Max Temp': 35.6,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hermanus',
#   'Lat': -34.4187,
#   'Lng': 19.2345,
#   'Max Temp': 73,
#   'Humidity': 77,
#   'Cloudiness': 1,
#   'Wind Speed': 4,
#   'Country': 'ZA',
#   'Current Description': 'clear sky'},
#  {'City': 'Pangody',
#   'Lat': 65.85,
#   'Lng': 74.4859,
#   'Max Temp': -19.98,
#   'Humidity': 87,
#   'Cloudiness': 98,
#   'Wind Speed': 12.59,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Carnarvon',
#   'Lat': -24.8667,
#   'Lng': 113.6333,
#   'Max Temp': 80.6,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'AU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Thompson',
#   'Lat': 55.7435,
#   'Lng': -97.8558,
#   'Max Temp': -34.6,
#   'Humidity': 67,
#   'Cloudiness': 75,
#   'Wind Speed': 12.66,
#   'Country': 'CA',
#   'Current Description': 'snow'},
#  {'City': 'Vardo',
#   'Lat': 70.3705,
#   'Lng': 31.1107,
#   'Max Temp': 23,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 18.41,
#   'Country': 'NO',
#   'Current Description': 'snow'},
#  {'City': 'Rikitea',
#   'Lat': -23.1203,
#   'Lng': -134.9692,
#   'Max Temp': 77.47,
#   'Humidity': 74,
#   'Cloudiness': 100,
#   'Wind Speed': 13.2,
#   'Country': 'PF',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Severnyy-Kospashskiy',
#   'Lat': 59.0925,
#   'Lng': 57.8008,
#   'Max Temp': 19,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 5.01,
#   'Country': 'RU',
#   'Current Description': 'light snow'},
#  {'City': 'Cabo San Lucas',
#   'Lat': 22.8909,
#   'Lng': -109.9124,
#   'Max Temp': 62.6,
#   'Humidity': 67,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Country': 'MX',
#   'Current Description': 'clear sky'},
#  {'City': 'Lugovoy',
#   'Lat': 42.9472,
#   'Lng': 72.7644,
#   'Max Temp': 45.1,
#   'Humidity': 53,
#   'Cloudiness': 100,
#   'Wind Speed': 6.85,
#   'Country': 'KZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Broken Hill',
#   'Lat': -31.95,
#   'Lng': 141.4333,
#   'Max Temp': 68,
#   'Humidity': 60,
#   'Cloudiness': 62,
#   'Wind Speed': 13.8,
#   'Country': 'AU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kapaa',
#   'Lat': 22.0752,
#   'Lng': -159.319,
#   'Max Temp': 59,
#   'Humidity': 82,
#   'Cloudiness': 13,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Current Description': 'few clouds'},
#  {'City': 'Mormugao',
#   'Lat': 15.4,
#   'Lng': 73.8,
#   'Max Temp': 82.4,
#   'Humidity': 61,
#   'Cloudiness': 47,
#   'Wind Speed': 4.61,
#   'Country': 'IN',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Avarua',
#   'Lat': -21.2078,
#   'Lng': -159.775,
#   'Max Temp': 75.2,
#   'Humidity': 94,
#   'Cloudiness': 15,
#   'Wind Speed': 2.3,
#   'Country': 'CK',
#   'Current Description': 'light rain'},
#  {'City': 'Vostok',
#   'Lat': 46.4856,
#   'Lng': 135.8833,
#   'Max Temp': -9.76,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 2.66,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Castro',
#   'Lat': -24.7911,
#   'Lng': -50.0119,
#   'Max Temp': 76.21,
#   'Humidity': 51,
#   'Cloudiness': 0,
#   'Wind Speed': 5.57,
#   'Country': 'BR',
#   'Current Description': 'clear sky'},
#  {'City': 'Vanimo',
#   'Lat': -2.6741,
#   'Lng': 141.3028,
#   'Max Temp': 77.22,
#   'Humidity': 84,
#   'Cloudiness': 98,
#   'Wind Speed': 3.51,
#   'Country': 'PG',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Huarmey',
#   'Lat': -10.0681,
#   'Lng': -78.1522,
#   'Max Temp': 75.56,
#   'Humidity': 65,
#   'Cloudiness': 90,
#   'Wind Speed': 9.06,
#   'Country': 'PE',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Mikhaylovka',
#   'Lat': 50.06,
#   'Lng': 43.2379,
#   'Max Temp': 19,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 5.01,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sao Filipe',
#   'Lat': 14.8961,
#   'Lng': -24.4956,
#   'Max Temp': 71.1,
#   'Humidity': 71,
#   'Cloudiness': 2,
#   'Wind Speed': 15.68,
#   'Country': 'CV',
#   'Current Description': 'clear sky'},
#  {'City': 'Saint-Louis',
#   'Lat': 16.3333,
#   'Lng': -15,
#   'Max Temp': 78.8,
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'SN',
#   'Current Description': 'clear sky'},
#  {'City': 'Yellowknife',
#   'Lat': 62.456,
#   'Lng': -114.3525,
#   'Max Temp': -45,
#   'Humidity': 73,
#   'Cloudiness': 1,
#   'Wind Speed': 2.3,
#   'Country': 'CA',
#   'Current Description': 'fog'},
#  {'City': 'Kodiak',
#   'Lat': 57.79,
#   'Lng': -152.4072,
#   'Max Temp': 23,
#   'Humidity': 74,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Imbituba',
#   'Lat': -28.24,
#   'Lng': -48.6703,
#   'Max Temp': 78.8,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 16.11,
#   'Country': 'BR',
#   'Current Description': 'clear sky'},
#  {'City': 'Jining',
#   'Lat': 35.405,
#   'Lng': 116.5814,
#   'Max Temp': 49.68,
#   'Humidity': 44,
#   'Cloudiness': 10,
#   'Wind Speed': 5.99,
#   'Country': 'CN',
#   'Current Description': 'clear sky'},
#  {'City': 'Port Blair',
#   'Lat': 11.6667,
#   'Lng': 92.75,
#   'Max Temp': 79.14,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 7.76,
#   'Country': 'IN',
#   'Current Description': 'clear sky'},
#  {'City': 'Provideniya',
#   'Lat': 64.3833,
#   'Lng': -173.3,
#   'Max Temp': 2.03,
#   'Humidity': 92,
#   'Cloudiness': 64,
#   'Wind Speed': 4.23,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'College',
#   'Lat': 64.8569,
#   'Lng': -147.8028,
#   'Max Temp': -9.4,
#   'Humidity': 70,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Current Description': 'light snow'},
#  {'City': 'Busselton',
#   'Lat': -33.65,
#   'Lng': 115.3333,
#   'Max Temp': 60.01,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 18.52,
#   'Country': 'AU',
#   'Current Description': 'light rain'},
#  {'City': 'Punta Arenas',
#   'Lat': -53.15,
#   'Lng': -70.9167,
#   'Max Temp': 51.8,
#   'Humidity': 50,
#   'Cloudiness': 40,
#   'Wind Speed': 18.41,
#   'Country': 'CL',
#   'Current Description': 'scattered clouds'},
#  {'City': 'East London',
#   'Lat': -33.0153,
#   'Lng': 27.9116,
#   'Max Temp': 77,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 11.5,
#   'Country': 'ZA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Roma',
#   'Lat': 43.2128,
#   'Lng': -75.4557,
#   'Max Temp': 26.6,
#   'Humidity': 54,
#   'Cloudiness': 90,
#   'Wind Speed': 9.22,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Crotone',
#   'Lat': 39.0851,
#   'Lng': 17.1178,
#   'Max Temp': 59,
#   'Humidity': 82,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'IT',
#   'Current Description': 'clear sky'},
#  {'City': 'La Macarena',
#   'Lat': 2.1837,
#   'Lng': -73.7849,
#   'Max Temp': 80.28,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 2.24,
#   'Country': 'CO',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Macquarie',
#   'Lat': -31.4333,
#   'Lng': 152.9167,
#   'Max Temp': 71.01,
#   'Humidity': 99,
#   'Cloudiness': 77,
#   'Wind Speed': 6.24,
#   'Country': 'AU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Muzhi',
#   'Lat': 65.3667,
#   'Lng': 64.6667,
#   'Max Temp': -28.59,
#   'Humidity': 84,
#   'Cloudiness': 95,
#   'Wind Speed': 11.48,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tiksi',
#   'Lat': 71.6872,
#   'Lng': 128.8694,
#   'Max Temp': -25.46,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 7.23,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Okhotsk',
#   'Lat': 59.3833,
#   'Lng': 143.3,
#   'Max Temp': 2.93,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 8.32,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pevek',
#   'Lat': 69.7008,
#   'Lng': 170.3133,
#   'Max Temp': -1.84,
#   'Humidity': 86,
#   'Cloudiness': 100,
#   'Wind Speed': 1.32,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Taraz',
#   'Lat': 42.9,
#   'Lng': 71.3667,
#   'Max Temp': 57.2,
#   'Humidity': 30,
#   'Cloudiness': 90,
#   'Wind Speed': 29.08,
#   'Country': 'KZ',
#   'Current Description': 'light rain'},
#  {'City': 'Diego De Almagro',
#   'Lat': -26.3667,
#   'Lng': -70.05,
#   'Max Temp': 83.03,
#   'Humidity': 16,
#   'Cloudiness': 0,
#   'Wind Speed': 10.83,
#   'Country': 'CL',
#   'Current Description': 'clear sky'},
#  {'City': 'Kirkuk',
#   'Lat': 35.4681,
#   'Lng': 44.3922,
#   'Max Temp': 55.13,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 3.4,
#   'Country': 'IQ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Alfred',
#   'Lat': -33.5906,
#   'Lng': 26.891,
#   'Max Temp': 77,
#   'Humidity': 87,
#   'Cloudiness': 15,
#   'Wind Speed': 3,
#   'Country': 'ZA',
#   'Current Description': 'few clouds'},
#  {'City': 'Tynda',
#   'Lat': 55.1667,
#   'Lng': 124.7167,
#   'Max Temp': -18.72,
#   'Humidity': 83,
#   'Cloudiness': 94,
#   'Wind Speed': 3.33,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Esperance',
#   'Lat': -33.8667,
#   'Lng': 121.9,
#   'Max Temp': 60.8,
#   'Humidity': 82,
#   'Cloudiness': 90,
#   'Wind Speed': 11.5,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ayacucho',
#   'Lat': -13.1583,
#   'Lng': -74.2239,
#   'Max Temp': 62.6,
#   'Humidity': 63,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'PE',
#   'Current Description': 'broken clouds'},
#  {'City': 'Faya',
#   'Lat': 18.3851,
#   'Lng': 42.4509,
#   'Max Temp': 55.4,
#   'Humidity': 71,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Country': 'SA',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Hilo',
#   'Lat': 19.7297,
#   'Lng': -155.09,
#   'Max Temp': 61,
#   'Humidity': 67,
#   'Cloudiness': 1,
#   'Wind Speed': 6.91,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Upernavik',
#   'Lat': 72.7868,
#   'Lng': -56.1549,
#   'Max Temp': 20.3,
#   'Humidity': 81,
#   'Cloudiness': 100,
#   'Wind Speed': 6.55,
#   'Country': 'GL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cidreira',
#   'Lat': -30.1811,
#   'Lng': -50.2056,
#   'Max Temp': 75.22,
#   'Humidity': 63,
#   'Cloudiness': 57,
#   'Wind Speed': 11.12,
#   'Country': 'BR',
#   'Current Description': 'broken clouds'},
#  {'City': 'Olsztyn',
#   'Lat': 53.7799,
#   'Lng': 20.4942,
#   'Max Temp': 12.2,
#   'Humidity': 67,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'PL',
#   'Current Description': 'clear sky'},
#  {'City': 'Butaritari',
#   'Lat': 3.0707,
#   'Lng': 172.7902,
#   'Max Temp': 80.89,
#   'Humidity': 81,
#   'Cloudiness': 91,
#   'Wind Speed': 21.9,
#   'Country': 'KI',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Aklavik',
#   'Lat': 68.2191,
#   'Lng': -135.0107,
#   'Max Temp': -27.4,
#   'Humidity': 68,
#   'Cloudiness': 20,
#   'Wind Speed': 1.57,
#   'Country': 'CA',
#   'Current Description': 'few clouds'},
#  {'City': 'San Vicente',
#   'Lat': -26.6167,
#   'Lng': -54.1333,
#   'Max Temp': 79.34,
#   'Humidity': 36,
#   'Cloudiness': 0,
#   'Wind Speed': 5.44,
#   'Country': 'AR',
#   'Current Description': 'clear sky'},
#  {'City': 'Yulara',
#   'Lat': -25.2406,
#   'Lng': 130.9889,
#   'Max Temp': 80.6,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 9.22,
#   'Country': 'AU',
#   'Current Description': 'clear sky'},
#  {'City': 'Puerto Del Rosario',
#   'Lat': 28.5004,
#   'Lng': -13.8627,
#   'Max Temp': 69.8,
#   'Humidity': 46,
#   'Cloudiness': 20,
#   'Wind Speed': 20.71,
#   'Country': 'ES',
#   'Current Description': 'few clouds'},
#  {'City': 'Nova Venecia',
#   'Lat': -18.7106,
#   'Lng': -40.4006,
#   'Max Temp': 87.42,
#   'Humidity': 57,
#   'Cloudiness': 100,
#   'Wind Speed': 12.26,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vaini',
#   'Lat': -21.2,
#   'Lng': -175.2,
#   'Max Temp': 77,
#   'Humidity': 100,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'TO',
#   'Current Description': 'broken clouds'},
#  {'City': 'Umm Lajj',
#   'Lat': 25.0213,
#   'Lng': 37.2685,
#   'Max Temp': 72.84,
#   'Humidity': 55,
#   'Cloudiness': 0,
#   'Wind Speed': 18.54,
#   'Country': 'SA',
#   'Current Description': 'clear sky'},
#  {'City': 'Broome',
#   'Lat': 42.2506,
#   'Lng': -75.833,
#   'Max Temp': 28.99,
#   'Humidity': 46,
#   'Cloudiness': 40,
#   'Wind Speed': 17.27,
#   'Country': 'US',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Flin Flon',
#   'Lat': 54.7682,
#   'Lng': -101.865,
#   'Max Temp': -31,
#   'Humidity': 68,
#   'Cloudiness': 1,
#   'Wind Speed': 9.22,
#   'Country': 'CA',
#   'Current Description': 'clear sky'},
#  {'City': 'Springfield',
#   'Lat': 37.2153,
#   'Lng': -93.2982,
#   'Max Temp': 37,
#   'Humidity': 64,
#   'Cloudiness': 90,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kupang',
#   'Lat': -10.1667,
#   'Lng': 123.5833,
#   'Max Temp': 79.63,
#   'Humidity': 83,
#   'Cloudiness': 98,
#   'Wind Speed': 7.52,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Rimbey',
#   'Lat': 52.6334,
#   'Lng': -114.2353,
#   'Max Temp': -7.6,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 2.3,
#   'Country': 'CA',
#   'Current Description': 'light snow'},
#  {'City': 'Gizo',
#   'Lat': -8.103,
#   'Lng': 156.8419,
#   'Max Temp': 82.15,
#   'Humidity': 78,
#   'Cloudiness': 69,
#   'Wind Speed': 14.92,
#   'Country': 'SB',
#   'Current Description': 'moderate rain'},
#  {'City': 'Ferrol',
#   'Lat': 43.4832,
#   'Lng': -8.2369,
#   'Max Temp': 52,
#   'Humidity': 52,
#   'Cloudiness': 9,
#   'Wind Speed': 7,
#   'Country': 'ES',
#   'Current Description': 'clear sky'},
#  {'City': 'Georgetown',
#   'Lat': 5.4112,
#   'Lng': 100.3354,
#   'Max Temp': 86,
#   'Humidity': 70,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'MY',
#   'Current Description': 'few clouds'},
#  {'City': 'Khatanga',
#   'Lat': 71.9667,
#   'Lng': 102.5,
#   'Max Temp': -36.92,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 5.12,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'Muros',
#   'Lat': 42.7762,
#   'Lng': -9.0603,
#   'Max Temp': 53.01,
#   'Humidity': 55,
#   'Cloudiness': 1,
#   'Wind Speed': 11.99,
#   'Country': 'ES',
#   'Current Description': 'clear sky'},
#  {'City': 'Westport',
#   'Lat': 41.1415,
#   'Lng': -73.3579,
#   'Max Temp': 39.99,
#   'Humidity': 60,
#   'Cloudiness': 1,
#   'Wind Speed': 10.36,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Buin',
#   'Lat': -33.7333,
#   'Lng': -70.75,
#   'Max Temp': 64.4,
#   'Humidity': 82,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'CL',
#   'Current Description': 'mist'},
#  {'City': 'Saint-Philippe',
#   'Lat': -21.3585,
#   'Lng': 55.7679,
#   'Max Temp': 82.4,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 8.05,
#   'Country': 'RE',
#   'Current Description': 'light rain'},
#  {'City': 'Manokwari',
#   'Lat': -0.8667,
#   'Lng': 134.0833,
#   'Max Temp': 78.73,
#   'Humidity': 82,
#   'Cloudiness': 100,
#   'Wind Speed': 5.03,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Marathon',
#   'Lat': 44.9,
#   'Lng': -89.7668,
#   'Max Temp': 0,
#   'Humidity': 71,
#   'Cloudiness': 1,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Dikson',
#   'Lat': 73.5069,
#   'Lng': 80.5464,
#   'Max Temp': -29.18,
#   'Humidity': 86,
#   'Cloudiness': 34,
#   'Wind Speed': 10.02,
#   'Country': 'RU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Kalas',
#   'Lat': 18.1667,
#   'Lng': 74.8,
#   'Max Temp': 74.77,
#   'Humidity': 24,
#   'Cloudiness': 0,
#   'Wind Speed': 7.81,
#   'Country': 'IN',
#   'Current Description': 'clear sky'},
#  {'City': 'Ponta Do Sol',
#   'Lat': 32.6667,
#   'Lng': -17.1,
#   'Max Temp': 62.6,
#   'Humidity': 51,
#   'Cloudiness': 40,
#   'Wind Speed': 12.66,
#   'Country': 'PT',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Doka',
#   'Lat': 13.5167,
#   'Lng': 35.7667,
#   'Max Temp': 73.71,
#   'Humidity': 18,
#   'Cloudiness': 48,
#   'Wind Speed': 10.2,
#   'Country': 'SD',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Iranshahr',
#   'Lat': 27.2025,
#   'Lng': 60.6848,
#   'Max Temp': 71.6,
#   'Humidity': 15,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'IR',
#   'Current Description': 'clear sky'},
#  {'City': 'Camacha',
#   'Lat': 33.0833,
#   'Lng': -16.3333,
#   'Max Temp': 62.6,
#   'Humidity': 55,
#   'Cloudiness': 40,
#   'Wind Speed': 21.85,
#   'Country': 'PT',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Cherskiy',
#   'Lat': 68.75,
#   'Lng': 161.3,
#   'Max Temp': -9.98,
#   'Humidity': 81,
#   'Cloudiness': 0,
#   'Wind Speed': 7.72,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'Port Hedland',
#   'Lat': -20.3167,
#   'Lng': 118.5667,
#   'Max Temp': 80.6,
#   'Humidity': 74,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Country': 'AU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Caravelas',
#   'Lat': -17.7125,
#   'Lng': -39.2481,
#   'Max Temp': 82.89,
#   'Humidity': 81,
#   'Cloudiness': 92,
#   'Wind Speed': 9.93,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ust-Karsk',
#   'Lat': 52.7011,
#   'Lng': 118.8077,
#   'Max Temp': -14.58,
#   'Humidity': 84,
#   'Cloudiness': 0,
#   'Wind Speed': 1.61,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'Cornwall',
#   'Lat': 45.0181,
#   'Lng': -74.7281,
#   'Max Temp': 23,
#   'Humidity': 63,
#   'Cloudiness': 90,
#   'Wind Speed': 14.97,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bilma',
#   'Lat': 18.6853,
#   'Lng': 12.9164,
#   'Max Temp': 81.05,
#   'Humidity': 15,
#   'Cloudiness': 19,
#   'Wind Speed': 9.31,
#   'Country': 'NE',
#   'Current Description': 'few clouds'},
#  {'City': 'Comodoro Rivadavia',
#   'Lat': -45.8667,
#   'Lng': -67.5,
#   'Max Temp': 60.8,
#   'Humidity': 67,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Country': 'AR',
#   'Current Description': 'broken clouds'},
#  {'City': 'Hellvik',
#   'Lat': 59.9156,
#   'Lng': 5.781,
#   'Max Temp': 28,
#   'Humidity': 46,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'NO',
#   'Current Description': 'clear sky'},
#  {'City': 'Komsomolskiy',
#   'Lat': 40.4272,
#   'Lng': 71.7189,
#   'Max Temp': 44.6,
#   'Humidity': 49,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Country': 'UZ',
#   'Current Description': 'mist'},
#  {'City': 'Moose Factory',
#   'Lat': 51.2585,
#   'Lng': -80.6094,
#   'Max Temp': 3.2,
#   'Humidity': 66,
#   'Cloudiness': 90,
#   'Wind Speed': 17.27,
#   'Country': 'CA',
#   'Current Description': 'light snow'},
#  {'City': 'Tasiilaq',
#   'Lat': 65.6145,
#   'Lng': -37.6368,
#   'Max Temp': 32,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 32.21,
#   'Country': 'GL',
#   'Current Description': 'snow'},
#  {'City': 'Jamestown',
#   'Lat': 42.097,
#   'Lng': -79.2353,
#   'Max Temp': 17.01,
#   'Humidity': 62,
#   'Cloudiness': 40,
#   'Wind Speed': 19.57,
#   'Country': 'US',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ipora',
#   'Lat': -16.4419,
#   'Lng': -51.1178,
#   'Max Temp': 84.25,
#   'Humidity': 69,
#   'Cloudiness': 49,
#   'Wind Speed': 4.16,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Chhapar',
#   'Lat': 27.8167,
#   'Lng': 74.4,
#   'Max Temp': 63.16,
#   'Humidity': 29,
#   'Cloudiness': 0,
#   'Wind Speed': 5.28,
#   'Country': 'IN',
#   'Current Description': 'clear sky'},
#  {'City': 'Qasigiannguit',
#   'Lat': 68.8193,
#   'Lng': -51.1922,
#   'Max Temp': 17.6,
#   'Humidity': 41,
#   'Cloudiness': 40,
#   'Wind Speed': 26.46,
#   'Country': 'GL',
#   'Current Description': 'snow'},
#  {'City': 'Atuona',
#   'Lat': -9.8,
#   'Lng': -139.0333,
#   'Max Temp': 80.29,
#   'Humidity': 76,
#   'Cloudiness': 60,
#   'Wind Speed': 22.68,
#   'Country': 'PF',
#   'Current Description': 'broken clouds'},
#  {'City': 'Khawhai',
#   'Lat': 23.3667,
#   'Lng': 93.1167,
#   'Max Temp': 43.05,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 2.01,
#   'Country': 'IN',
#   'Current Description': 'clear sky'},
#  {'City': 'Raton',
#   'Lat': 36.9034,
#   'Lng': -104.4391,
#   'Max Temp': 30.2,
#   'Humidity': 37,
#   'Cloudiness': 1,
#   'Wind Speed': 10.18,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Eshowe',
#   'Lat': -28.8865,
#   'Lng': 31.4699,
#   'Max Temp': 75.54,
#   'Humidity': 83,
#   'Cloudiness': 38,
#   'Wind Speed': 7.92,
#   'Country': 'ZA',
#   'Current Description': 'light rain'},
#  {'City': 'Koumac',
#   'Lat': -20.5667,
#   'Lng': 164.2833,
#   'Max Temp': 76.69,
#   'Humidity': 75,
#   'Cloudiness': 1,
#   'Wind Speed': 1.21,
#   'Country': 'NC',
#   'Current Description': 'clear sky'},
#  {'City': 'Tupelo',
#   'Lat': 34.2576,
#   'Lng': -88.7034,
#   'Max Temp': 44.01,
#   'Humidity': 81,
#   'Cloudiness': 90,
#   'Wind Speed': 7.14,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sibolga',
#   'Lat': 1.7427,
#   'Lng': 98.7792,
#   'Max Temp': 77.86,
#   'Humidity': 81,
#   'Cloudiness': 66,
#   'Wind Speed': 3.87,
#   'Country': 'ID',
#   'Current Description': 'broken clouds'},
#  {'City': 'Boa Vista',
#   'Lat': 2.8197,
#   'Lng': -60.6733,
#   'Max Temp': 86,
#   'Humidity': 54,
#   'Cloudiness': 90,
#   'Wind Speed': 13.8,
#   'Country': 'BR',
#   'Current Description': 'light rain'},
#  {'City': 'Constitucion',
#   'Lat': -35.3333,
#   'Lng': -72.4167,
#   'Max Temp': 63.75,
#   'Humidity': 74,
#   'Cloudiness': 84,
#   'Wind Speed': 3.6,
#   'Country': 'CL',
#   'Current Description': 'broken clouds'},
#  {'City': 'Saurimo',
#   'Lat': -9.6608,
#   'Lng': 20.3916,
#   'Max Temp': 71.46,
#   'Humidity': 91,
#   'Cloudiness': 99,
#   'Wind Speed': 5.26,
#   'Country': 'AO',
#   'Current Description': 'light rain'},
#  {'City': 'Victoria',
#   'Lat': 22.2855,
#   'Lng': 114.1577,
#   'Max Temp': 68,
#   'Humidity': 69,
#   'Cloudiness': 0,
#   'Wind Speed': 4.54,
#   'Country': 'HK',
#   'Current Description': 'clear sky'},
#  {'City': 'Ostrovnoy',
#   'Lat': 68.0531,
#   'Lng': 39.5131,
#   'Max Temp': 15.39,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 12.64,
#   'Country': 'RU',
#   'Current Description': 'light snow'},
#  {'City': 'Raudeberg',
#   'Lat': 61.9875,
#   'Lng': 5.1352,
#   'Max Temp': 27,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 5.75,
#   'Country': 'NO',
#   'Current Description': 'clear sky'},
#  {'City': 'Kaeo',
#   'Lat': -35.1,
#   'Lng': 173.7833,
#   'Max Temp': 62.01,
#   'Humidity': 90,
#   'Cloudiness': 91,
#   'Wind Speed': 1.99,
#   'Country': 'NZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Puerto Ayora',
#   'Lat': -0.7393,
#   'Lng': -90.3518,
#   'Max Temp': 82.4,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 17.27,
#   'Country': 'EC',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Lyubech',
#   'Lat': 51.7026,
#   'Lng': 30.6569,
#   'Max Temp': 11.19,
#   'Humidity': 92,
#   'Cloudiness': 95,
#   'Wind Speed': 9.8,
#   'Country': 'UA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dhidhdhoo',
#   'Lat': 6.8833,
#   'Lng': 73.1,
#   'Max Temp': 82.17,
#   'Humidity': 75,
#   'Cloudiness': 79,
#   'Wind Speed': 10.67,
#   'Country': 'MV',
#   'Current Description': 'broken clouds'},
#  {'City': 'Zhanaozen',
#   'Lat': 43.3,
#   'Lng': 52.8,
#   'Max Temp': 35.55,
#   'Humidity': 74,
#   'Cloudiness': 25,
#   'Wind Speed': 10.16,
#   'Country': 'KZ',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Namwala',
#   'Lat': -15.7504,
#   'Lng': 26.4384,
#   'Max Temp': 77.88,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 4.16,
#   'Country': 'ZM',
#   'Current Description': 'light rain'},
#  {'City': 'Saint-Augustin',
#   'Lat': 51.226,
#   'Lng': -58.6502,
#   'Max Temp': 32.14,
#   'Humidity': 98,
#   'Cloudiness': 100,
#   'Wind Speed': 11.83,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Necochea',
#   'Lat': -38.5473,
#   'Lng': -58.7368,
#   'Max Temp': 73.06,
#   'Humidity': 57,
#   'Cloudiness': 7,
#   'Wind Speed': 14.81,
#   'Country': 'AR',
#   'Current Description': 'clear sky'},
#  {'City': 'Romny',
#   'Lat': 50.751,
#   'Lng': 33.4747,
#   'Max Temp': 14.23,
#   'Humidity': 96,
#   'Cloudiness': 100,
#   'Wind Speed': 8.9,
#   'Country': 'UA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Namatanai',
#   'Lat': -3.6667,
#   'Lng': 152.4333,
#   'Max Temp': 79.48,
#   'Humidity': 79,
#   'Cloudiness': 84,
#   'Wind Speed': 2.19,
#   'Country': 'PG',
#   'Current Description': 'broken clouds'},
#  {'City': 'San Estanislao',
#   'Lat': 10.3983,
#   'Lng': -75.1511,
#   'Max Temp': 86,
#   'Humidity': 70,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Country': 'CO',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Saskylakh',
#   'Lat': 71.9167,
#   'Lng': 114.0833,
#   'Max Temp': -37.82,
#   'Humidity': 80,
#   'Cloudiness': 69,
#   'Wind Speed': 4.61,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Torbay',
#   'Lat': 47.6666,
#   'Lng': -52.7314,
#   'Max Temp': 37.99,
#   'Humidity': 80,
#   'Cloudiness': 90,
#   'Wind Speed': 9.22,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Usinsk',
#   'Lat': 65.9939,
#   'Lng': 57.5281,
#   'Max Temp': -29.02,
#   'Humidity': 83,
#   'Cloudiness': 6,
#   'Wind Speed': 14.23,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'Ancud',
#   'Lat': -41.8697,
#   'Lng': -73.8203,
#   'Max Temp': 73.99,
#   'Humidity': 53,
#   'Cloudiness': 0,
#   'Wind Speed': 10.36,
#   'Country': 'CL',
#   'Current Description': 'clear sky'},
#  {'City': 'Onega',
#   'Lat': 63.9061,
#   'Lng': 38.1404,
#   'Max Temp': 9.75,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 7.85,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vila',
#   'Lat': 42.0304,
#   'Lng': -8.1588,
#   'Max Temp': 46,
#   'Humidity': 81,
#   'Cloudiness': 82,
#   'Wind Speed': 8.14,
#   'Country': 'PT',
#   'Current Description': 'broken clouds'},
#  {'City': 'Cacoal',
#   'Lat': -11.4386,
#   'Lng': -61.4472,
#   'Max Temp': 76.75,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 3.31,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Neiafu',
#   'Lat': -18.65,
#   'Lng': -173.9833,
#   'Max Temp': 78.8,
#   'Humidity': 89,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Country': 'TO',
#   'Current Description': 'heavy intensity rain'},
#  {'City': 'Iqaluit',
#   'Lat': 63.7506,
#   'Lng': -68.5145,
#   'Max Temp': 21.2,
#   'Humidity': 86,
#   'Cloudiness': 75,
#   'Wind Speed': 14.97,
#   'Country': 'CA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Hasaki',
#   'Lat': 35.7333,
#   'Lng': 140.8333,
#   'Max Temp': 42.8,
#   'Humidity': 87,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'JP',
#   'Current Description': 'few clouds'},
#  {'City': 'Ballina',
#   'Lat': -28.8667,
#   'Lng': 153.5667,
#   'Max Temp': 71.6,
#   'Humidity': 88,
#   'Cloudiness': 91,
#   'Wind Speed': 2.51,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kudahuvadhoo',
#   'Lat': 2.6708,
#   'Lng': 72.8944,
#   'Max Temp': 81.82,
#   'Humidity': 76,
#   'Cloudiness': 67,
#   'Wind Speed': 13.22,
#   'Country': 'MV',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kavieng',
#   'Lat': -2.5744,
#   'Lng': 150.7967,
#   'Max Temp': 81.86,
#   'Humidity': 71,
#   'Cloudiness': 96,
#   'Wind Speed': 3.78,
#   'Country': 'PG',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Alpena',
#   'Lat': 45.0617,
#   'Lng': -83.4327,
#   'Max Temp': 15.01,
#   'Humidity': 67,
#   'Cloudiness': 90,
#   'Wind Speed': 16.11,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Hardy',
#   'Lat': 50.6996,
#   'Lng': -127.4199,
#   'Max Temp': 44.6,
#   'Humidity': 100,
#   'Cloudiness': 90,
#   'Wind Speed': 6.91,
#   'Country': 'CA',
#   'Current Description': 'light rain'},
#  {'City': 'Qaanaaq',
#   'Lat': 77.484,
#   'Lng': -69.3632,
#   'Max Temp': 9.66,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 7.31,
#   'Country': 'GL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Codrington',
#   'Lat': -38.2667,
#   'Lng': 141.9667,
#   'Max Temp': 59.23,
#   'Humidity': 79,
#   'Cloudiness': 98,
#   'Wind Speed': 15.35,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port-Cartier',
#   'Lat': 50.0334,
#   'Lng': -66.8654,
#   'Max Temp': 30.99,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Country': 'CA',
#   'Current Description': 'snow'},
#  {'City': 'Katsuura',
#   'Lat': 35.1333,
#   'Lng': 140.3,
#   'Max Temp': 48.99,
#   'Humidity': 87,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Country': 'JP',
#   'Current Description': 'few clouds'},
#  {'City': 'Malia',
#   'Lat': 35.2833,
#   'Lng': 25.4667,
#   'Max Temp': 68,
#   'Humidity': 60,
#   'Cloudiness': 0,
#   'Wind Speed': 2.3,
#   'Country': 'GR',
#   'Current Description': 'clear sky'},
#  {'City': 'Tuatapere',
#   'Lat': -46.1333,
#   'Lng': 167.6833,
#   'Max Temp': 51.49,
#   'Humidity': 86,
#   'Cloudiness': 1,
#   'Wind Speed': 3.22,
#   'Country': 'NZ',
#   'Current Description': 'clear sky'},
#  {'City': 'Rawson',
#   'Lat': -43.3002,
#   'Lng': -65.1023,
#   'Max Temp': 66.06,
#   'Humidity': 52,
#   'Cloudiness': 14,
#   'Wind Speed': 18.3,
#   'Country': 'AR',
#   'Current Description': 'few clouds'},
#  {'City': 'Jacksonville',
#   'Lat': 30.3322,
#   'Lng': -81.6556,
#   'Max Temp': 52,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 11.5,
#   'Country': 'US',
#   'Current Description': 'light rain'},
#  {'City': 'Nome',
#   'Lat': 64.5011,
#   'Lng': -165.4064,
#   'Max Temp': 14,
#   'Humidity': 85,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Saldanha',
#   'Lat': -33.0117,
#   'Lng': 17.9442,
#   'Max Temp': 77,
#   'Humidity': 61,
#   'Cloudiness': 20,
#   'Wind Speed': 24.16,
#   'Country': 'ZA',
#   'Current Description': 'few clouds'},
#  {'City': 'Orange',
#   'Lat': 33.7,
#   'Lng': -117.7675,
#   'Max Temp': 48.2,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 0.89,
#   'Country': 'US',
#   'Current Description': 'broken clouds'},
#  {'City': 'Ribeira Grande',
#   'Lat': 38.5167,
#   'Lng': -28.7,
#   'Max Temp': 60.8,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 20.71,
#   'Country': 'PT',
#   'Current Description': 'broken clouds'},
#  {'City': 'Coracao De Jesus',
#   'Lat': -16.6853,
#   'Lng': -44.365,
#   'Max Temp': 72.09,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 8.9,
#   'Country': 'BR',
#   'Current Description': 'light rain'},
#  {'City': 'Hovd',
#   'Lat': 48.0056,
#   'Lng': 91.6419,
#   'Max Temp': 11.55,
#   'Humidity': 90,
#   'Cloudiness': 86,
#   'Wind Speed': 1.68,
#   'Country': 'MN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Idaho Falls',
#   'Lat': 43.4666,
#   'Lng': -112.0341,
#   'Max Temp': 26.6,
#   'Humidity': 93,
#   'Cloudiness': 90,
#   'Wind Speed': 18.41,
#   'Country': 'US',
#   'Current Description': 'light snow'},
#  {'City': 'Kaitangata',
#   'Lat': -46.2817,
#   'Lng': 169.8464,
#   'Max Temp': 50.25,
#   'Humidity': 93,
#   'Cloudiness': 2,
#   'Wind Speed': 3.51,
#   'Country': 'NZ',
#   'Current Description': 'clear sky'},
#  {'City': 'Avanigadda',
#   'Lat': 16.0215,
#   'Lng': 80.9181,
#   'Max Temp': 73.4,
#   'Humidity': 64,
#   'Cloudiness': 25,
#   'Wind Speed': 3.44,
#   'Country': 'IN',
#   'Current Description': 'haze'},
#  {'City': 'Port-Gentil',
#   'Lat': -0.7193,
#   'Lng': 8.7815,
#   'Max Temp': 84.2,
#   'Humidity': 79,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Country': 'GA',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Gat',
#   'Lat': 31.61,
#   'Lng': 34.7642,
#   'Max Temp': 64.99,
#   'Humidity': 100,
#   'Cloudiness': 21,
#   'Wind Speed': 5.12,
#   'Country': 'IL',
#   'Current Description': 'few clouds'},
#  {'City': 'San Cristobal',
#   'Lat': 7.7669,
#   'Lng': -72.225,
#   'Max Temp': 68.25,
#   'Humidity': 89,
#   'Cloudiness': 100,
#   'Wind Speed': 4.23,
#   'Country': 'VE',
#   'Current Description': 'overcast clouds'},
#  {'City': 'The Valley',
#   'Lat': 18.217,
#   'Lng': -63.0578,
#   'Max Temp': 78.8,
#   'Humidity': 69,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Country': 'AI',
#   'Current Description': 'few clouds'},
#  {'City': 'Portland',
#   'Lat': 45.5234,
#   'Lng': -122.6762,
#   'Max Temp': 42.01,
#   'Humidity': 87,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Current Description': 'broken clouds'},
#  {'City': 'Bacolod',
#   'Lat': 10.6667,
#   'Lng': 122.95,
#   'Max Temp': 77.52,
#   'Humidity': 81,
#   'Cloudiness': 69,
#   'Wind Speed': 12.17,
#   'Country': 'PH',
#   'Current Description': 'broken clouds'},
#  {'City': 'Peachland',
#   'Lat': 49.7665,
#   'Lng': -119.7357,
#   'Max Temp': 35.6,
#   'Humidity': 87,
#   'Cloudiness': 100,
#   'Wind Speed': 6.91,
#   'Country': 'CA',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Palmer',
#   'Lat': 42.1584,
#   'Lng': -72.3287,
#   'Max Temp': 37,
#   'Humidity': 51,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Current Description': 'few clouds'},
#  {'City': 'Los Llanos De Aridane',
#   'Lat': 28.6585,
#   'Lng': -17.9182,
#   'Max Temp': 66.2,
#   'Humidity': 52,
#   'Cloudiness': 20,
#   'Wind Speed': 28.77,
#   'Country': 'ES',
#   'Current Description': 'few clouds'},
#  {'City': 'Sorong',
#   'Lat': -0.8833,
#   'Lng': 131.25,
#   'Max Temp': 81.03,
#   'Humidity': 79,
#   'Cloudiness': 100,
#   'Wind Speed': 1.43,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Tommot',
#   'Lat': 58.9564,
#   'Lng': 126.2925,
#   'Max Temp': -18.85,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Barrow',
#   'Lat': 71.2906,
#   'Lng': -156.7887,
#   'Max Temp': -2.2,
#   'Humidity': 71,
#   'Cloudiness': 90,
#   'Wind Speed': 10.36,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pisco',
#   'Lat': -13.7,
#   'Lng': -76.2167,
#   'Max Temp': 73,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Country': 'PE',
#   'Current Description': 'broken clouds'},
#  {'City': 'Hamilton',
#   'Lat': 39.1834,
#   'Lng': -84.5333,
#   'Max Temp': 28,
#   'Humidity': 54,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Emerald',
#   'Lat': -23.5333,
#   'Lng': 148.1667,
#   'Max Temp': 84.2,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 8.05,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Arco',
#   'Lat': 45.9177,
#   'Lng': 10.8867,
#   'Max Temp': 50,
#   'Humidity': 76,
#   'Cloudiness': 100,
#   'Wind Speed': 1.01,
#   'Country': 'IT',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Norman Wells',
#   'Lat': 65.282,
#   'Lng': -126.8329,
#   'Max Temp': -38.2,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'CA',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Lorengau',
#   'Lat': -2.0226,
#   'Lng': 147.2712,
#   'Max Temp': 81.64,
#   'Humidity': 79,
#   'Cloudiness': 51,
#   'Wind Speed': 6.04,
#   'Country': 'PG',
#   'Current Description': 'broken clouds'},
#  {'City': 'Tomari',
#   'Lat': 47.7658,
#   'Lng': 142.0683,
#   'Max Temp': 2.66,
#   'Humidity': 90,
#   'Cloudiness': 81,
#   'Wind Speed': 5.55,
#   'Country': 'RU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Touros',
#   'Lat': -5.1989,
#   'Lng': -35.4608,
#   'Max Temp': 87.8,
#   'Humidity': 51,
#   'Cloudiness': 40,
#   'Wind Speed': 14.97,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Port Elizabeth',
#   'Lat': -33.918,
#   'Lng': 25.5701,
#   'Max Temp': 82.4,
#   'Humidity': 65,
#   'Cloudiness': 20,
#   'Wind Speed': 5.75,
#   'Country': 'ZA',
#   'Current Description': 'few clouds'},
#  {'City': 'Kahului',
#   'Lat': 20.8947,
#   'Lng': -156.47,
#   'Max Temp': 62.6,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Current Description': 'broken clouds'},
#  {'City': 'Abha',
#   'Lat': 18.2164,
#   'Lng': 42.5053,
#   'Max Temp': 55.4,
#   'Humidity': 71,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Country': 'SA',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Tateyama',
#   'Lat': 34.9833,
#   'Lng': 139.8667,
#   'Max Temp': 48.99,
#   'Humidity': 87,
#   'Cloudiness': 20,
#   'Wind Speed': 11.5,
#   'Country': 'JP',
#   'Current Description': 'few clouds'},
#  {'City': 'Petropavlovsk-Kamchatskiy',
#   'Lat': 53.0452,
#   'Lng': 158.6483,
#   'Max Temp': 21.2,
#   'Humidity': 73,
#   'Cloudiness': 100,
#   'Wind Speed': 24.61,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Magadan',
#   'Lat': 59.5667,
#   'Lng': 150.8,
#   'Max Temp': 2.03,
#   'Humidity': 88,
#   'Cloudiness': 85,
#   'Wind Speed': 12.3,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Cockburn Town',
#   'Lat': 21.4612,
#   'Lng': -71.1419,
#   'Max Temp': 80.6,
#   'Humidity': 69,
#   'Cloudiness': 40,
#   'Wind Speed': 19.57,
#   'Country': 'TC',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Cayenne',
#   'Lat': 4.9333,
#   'Lng': -52.3333,
#   'Max Temp': 78.8,
#   'Humidity': 94,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'GF',
#   'Current Description': 'mist'},
#  {'City': 'Prince Rupert',
#   'Lat': 54.3161,
#   'Lng': -130.3201,
#   'Max Temp': 37.4,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 3.44,
#   'Country': 'CA',
#   'Current Description': 'light rain'},
#  {'City': 'Zelenoborskiy',
#   'Lat': 66.845,
#   'Lng': 32.3622,
#   'Max Temp': 18,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 10.71,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pangnirtung',
#   'Lat': 66.1451,
#   'Lng': -65.7125,
#   'Max Temp': 14,
#   'Humidity': 85,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'CA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Svetlogorsk',
#   'Lat': 52.6333,
#   'Lng': 29.7333,
#   'Max Temp': 6.08,
#   'Humidity': 93,
#   'Cloudiness': 43,
#   'Wind Speed': 8.66,
#   'Country': 'BY',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Ilulissat',
#   'Lat': 69.2167,
#   'Lng': -51.1,
#   'Max Temp': 17.6,
#   'Humidity': 41,
#   'Cloudiness': 40,
#   'Wind Speed': 26.46,
#   'Country': 'GL',
#   'Current Description': 'snow'},
#  {'City': 'Srednekolymsk',
#   'Lat': 67.45,
#   'Lng': 153.6833,
#   'Max Temp': -21.84,
#   'Humidity': 85,
#   'Cloudiness': 7,
#   'Wind Speed': 2.33,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'Honningsvag',
#   'Lat': 70.9821,
#   'Lng': 25.9704,
#   'Max Temp': 28.27,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 24,
#   'Country': 'NO',
#   'Current Description': 'light snow'},
#  {'City': 'Laguna',
#   'Lat': 38.421,
#   'Lng': -121.4238,
#   'Max Temp': 39,
#   'Humidity': 93,
#   'Cloudiness': 1,
#   'Wind Speed': 1.86,
#   'Country': 'US',
#   'Current Description': 'mist'},
#  {'City': 'Guerrero Negro',
#   'Lat': 27.9769,
#   'Lng': -114.0611,
#   'Max Temp': 60.44,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 7.76,
#   'Country': 'MX',
#   'Current Description': 'clear sky'},
#  {'City': 'Talnakh',
#   'Lat': 69.4865,
#   'Lng': 88.3972,
#   'Max Temp': -29.24,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 3.56,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'Colares',
#   'Lat': 38.7992,
#   'Lng': -9.4469,
#   'Max Temp': 54,
#   'Humidity': 76,
#   'Cloudiness': 75,
#   'Wind Speed': 19.57,
#   'Country': 'PT',
#   'Current Description': 'broken clouds'},
#  {'City': 'Pinyug',
#   'Lat': 60.251,
#   'Lng': 47.7842,
#   'Max Temp': -5.3,
#   'Humidity': 90,
#   'Cloudiness': 100,
#   'Wind Speed': 10.98,
#   'Country': 'RU',
#   'Current Description': 'light snow'},
#  {'City': 'Chuy',
#   'Lat': -33.6971,
#   'Lng': -53.4616,
#   'Max Temp': 79.66,
#   'Humidity': 50,
#   'Cloudiness': 0,
#   'Wind Speed': 10.09,
#   'Country': 'UY',
#   'Current Description': 'clear sky'},
#  {'City': 'Narovchat',
#   'Lat': 53.8765,
#   'Lng': 43.6946,
#   'Max Temp': 2.26,
#   'Humidity': 92,
#   'Cloudiness': 98,
#   'Wind Speed': 11.99,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dingle',
#   'Lat': 10.9995,
#   'Lng': 122.6711,
#   'Max Temp': 75.36,
#   'Humidity': 91,
#   'Cloudiness': 65,
#   'Wind Speed': 9.55,
#   'Country': 'PH',
#   'Current Description': 'broken clouds'},
#  {'City': 'Ozernovskiy',
#   'Lat': 51.5,
#   'Lng': 156.5167,
#   'Max Temp': 14.29,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 7.81,
#   'Country': 'RU',
#   'Current Description': 'light snow'},
#  {'City': 'Pangkalanbuun',
#   'Lat': -2.6833,
#   'Lng': 111.6167,
#   'Max Temp': 75.4,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 2.73,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kaihua',
#   'Lat': 23.3687,
#   'Lng': 104.28,
#   'Max Temp': 56.46,
#   'Humidity': 89,
#   'Cloudiness': 56,
#   'Wind Speed': 6.58,
#   'Country': 'CN',
#   'Current Description': 'broken clouds'},
#  {'City': 'Berlevag',
#   'Lat': 70.8578,
#   'Lng': 29.0864,
#   'Max Temp': 26.55,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 23.35,
#   'Country': 'NO',
#   'Current Description': 'light snow'},
#  {'City': 'Myshkin',
#   'Lat': 57.7897,
#   'Lng': 38.4545,
#   'Max Temp': -2.81,
#   'Humidity': 91,
#   'Cloudiness': 100,
#   'Wind Speed': 9.19,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Thinadhoo',
#   'Lat': 0.5333,
#   'Lng': 72.9333,
#   'Max Temp': 81.73,
#   'Humidity': 75,
#   'Cloudiness': 68,
#   'Wind Speed': 12.48,
#   'Country': 'MV',
#   'Current Description': 'broken clouds'},
#  {'City': 'Rudnichnyy',
#   'Lat': 59.617,
#   'Lng': 52.4703,
#   'Max Temp': -1.53,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 9.51,
#   'Country': 'RU',
#   'Current Description': 'light snow'},
#  {'City': 'Bhanvad',
#   'Lat': 21.9264,
#   'Lng': 69.7736,
#   'Max Temp': 66.87,
#   'Humidity': 27,
#   'Cloudiness': 0,
#   'Wind Speed': 11.05,
#   'Country': 'IN',
#   'Current Description': 'clear sky'},
#  {'City': 'Mahebourg',
#   'Lat': -20.4081,
#   'Lng': 57.7,
#   'Max Temp': 80.6,
#   'Humidity': 74,
#   'Cloudiness': 20,
#   'Wind Speed': 8.05,
#   'Country': 'MU',
#   'Current Description': 'few clouds'},
#  {'City': 'Dong Hoi',
#   'Lat': 17.4833,
#   'Lng': 106.6,
#   'Max Temp': 68.27,
#   'Humidity': 91,
#   'Cloudiness': 71,
#   'Wind Speed': 2.44,
#   'Country': 'VN',
#   'Current Description': 'broken clouds'},
#  {'City': 'Airai',
#   'Lat': -8.9266,
#   'Lng': 125.4092,
#   'Max Temp': 61,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 1.97,
#   'Country': 'TL',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Hohhot',
#   'Lat': 40.8106,
#   'Lng': 111.6522,
#   'Max Temp': 24.8,
#   'Humidity': 58,
#   'Cloudiness': 0,
#   'Wind Speed': 11.18,
#   'Country': 'CN',
#   'Current Description': 'clear sky'},
#  {'City': 'Kruisfontein',
#   'Lat': -34.0033,
#   'Lng': 24.7314,
#   'Max Temp': 77,
#   'Humidity': 73,
#   'Cloudiness': 0,
#   'Wind Speed': 5.01,
#   'Country': 'ZA',
#   'Current Description': 'clear sky'},
#  {'City': 'Lompoc',
#   'Lat': 34.6391,
#   'Lng': -120.4579,
#   'Max Temp': 45,
#   'Humidity': 93,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Santa Maria',
#   'Lat': -29.6842,
#   'Lng': -53.8069,
#   'Max Temp': 73.4,
#   'Humidity': 60,
#   'Cloudiness': 40,
#   'Wind Speed': 4.61,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Chimbote',
#   'Lat': -9.0853,
#   'Lng': -78.5783,
#   'Max Temp': 75.18,
#   'Humidity': 65,
#   'Cloudiness': 100,
#   'Wind Speed': 7.4,
#   'Country': 'PE',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Ayan',
#   'Lat': 56.45,
#   'Lng': 138.1667,
#   'Max Temp': -6.47,
#   'Humidity': 83,
#   'Cloudiness': 100,
#   'Wind Speed': 16.49,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Vila Franca Do Campo',
#   'Lat': 37.7167,
#   'Lng': -25.4333,
#   'Max Temp': 59,
#   'Humidity': 88,
#   'Cloudiness': 20,
#   'Wind Speed': 17.27,
#   'Country': 'PT',
#   'Current Description': 'few clouds'},
#  {'City': 'Humberto De Campos',
#   'Lat': -2.5983,
#   'Lng': -43.4611,
#   'Max Temp': 89.11,
#   'Humidity': 54,
#   'Cloudiness': 98,
#   'Wind Speed': 10.92,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Seguela',
#   'Lat': 7.9611,
#   'Lng': -6.6731,
#   'Max Temp': 100.49,
#   'Humidity': 23,
#   'Cloudiness': 83,
#   'Wind Speed': 4.25,
#   'Country': 'CI',
# ...
#  {'City': 'Mbalmayo',
#   'Lat': 3.5167,
#   'Lng': 11.5,
#   'Max Temp': 91.4,
#   'Humidity': 38,
#   'Cloudiness': 40,
#   'Wind Speed': 2.3,
#   'Country': 'CM',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Paragominas',
#   'Lat': -2.9667,
#   'Lng': -47.4833,
#   'Max Temp': 90.77,
#   'Humidity': 49,
#   'Cloudiness': 85,
#   'Wind Speed': 4.99,
#   'Country': 'BR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Murud',
#   'Lat': 18.3258,
#   'Lng': 72.965,
#   'Max Temp': 75.54,
#   'Humidity': 57,
#   'Cloudiness': 0,
#   'Wind Speed': 9.19,
#   'Country': 'IN',
#   'Current Description': 'clear sky'},
#  {'City': 'Poronaysk',
#   'Lat': 49.2167,
#   'Lng': 143.1167,
#   'Max Temp': -10.64,
#   'Humidity': 86,
#   'Cloudiness': 1,
#   'Wind Speed': 4.16,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'Prokhorovka',
#   'Lat': 51.0374,
#   'Lng': 36.7325,
#   'Max Temp': 15.8,
#   'Humidity': 73,
#   'Cloudiness': 75,
#   'Wind Speed': 13.42,
#   'Country': 'RU',
#   'Current Description': 'snow'},
#  {'City': 'Uyovu',
#   'Lat': -3.2833,
#   'Lng': 31.5258,
#   'Max Temp': 70.43,
#   'Humidity': 83,
#   'Cloudiness': 94,
#   'Wind Speed': 2.35,
#   'Country': 'TZ',
#   'Current Description': 'overcast clouds'},
#  {'City': 'La Carolina',
#   'Lat': 38.2756,
#   'Lng': -3.6153,
#   'Max Temp': 57.99,
#   'Humidity': 62,
#   'Cloudiness': 84,
#   'Wind Speed': 11.14,
#   'Country': 'ES',
#   'Current Description': 'broken clouds'},
#  {'City': 'Namibe',
#   'Lat': -15.1961,
#   'Lng': 12.1522,
#   'Max Temp': 75.43,
#   'Humidity': 70,
#   'Cloudiness': 25,
#   'Wind Speed': 12.15,
#   'Country': 'AO',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Natal',
#   'Lat': -5.795,
#   'Lng': -35.2094,
#   'Max Temp': 87.8,
#   'Humidity': 51,
#   'Cloudiness': 40,
#   'Wind Speed': 11.5,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Rocha',
#   'Lat': -34.4833,
#   'Lng': -54.3333,
#   'Max Temp': 83.16,
#   'Humidity': 41,
#   'Cloudiness': 0,
#   'Wind Speed': 13,
#   'Country': 'UY',
#   'Current Description': 'clear sky'},
#  {'City': 'Manono',
#   'Lat': -7.3,
#   'Lng': 27.4167,
#   'Max Temp': 77.7,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 3.42,
#   'Country': 'CD',
#   'Current Description': 'light rain'},
#  {'City': 'Istmina',
#   'Lat': 5.1605,
#   'Lng': -76.684,
#   'Max Temp': 90.39,
#   'Humidity': 60,
#   'Cloudiness': 97,
#   'Wind Speed': 1.25,
#   'Country': 'CO',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Havelock',
#   'Lat': 34.8791,
#   'Lng': -76.9013,
#   'Max Temp': 48.99,
#   'Humidity': 61,
#   'Cloudiness': 75,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Current Description': 'broken clouds'},
#  {'City': 'Kuytun',
#   'Lat': 54.3419,
#   'Lng': 101.5036,
#   'Max Temp': 6.48,
#   'Humidity': 93,
#   'Cloudiness': 100,
#   'Wind Speed': 5.61,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Najran',
#   'Lat': 17.4924,
#   'Lng': 44.1277,
#   'Max Temp': 78.8,
#   'Humidity': 29,
#   'Cloudiness': 40,
#   'Wind Speed': 14.97,
#   'Country': 'SA',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Zemio',
#   'Lat': 5.0314,
#   'Lng': 25.1361,
#   'Max Temp': 87.87,
#   'Humidity': 17,
#   'Cloudiness': 92,
#   'Wind Speed': 3.76,
#   'Country': 'CF',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Lubango',
#   'Lat': -14.9172,
#   'Lng': 13.4925,
#   'Max Temp': 71.6,
#   'Humidity': 42,
#   'Cloudiness': 75,
#   'Wind Speed': 4.61,
#   'Country': 'AO',
#   'Current Description': 'broken clouds'},
#  {'City': 'Champerico',
#   'Lat': 14.3,
#   'Lng': -91.9167,
#   'Max Temp': 80.6,
#   'Humidity': 65,
#   'Cloudiness': 0,
#   'Wind Speed': 6.44,
#   'Country': 'GT',
#   'Current Description': 'clear sky'},
#  {'City': 'Dzilam Gonzalez',
#   'Lat': 21.2833,
#   'Lng': -88.9333,
#   'Max Temp': 83.64,
#   'Humidity': 59,
#   'Cloudiness': 13,
#   'Wind Speed': 8.3,
#   'Country': 'MX',
#   'Current Description': 'few clouds'},
#  {'City': 'Ampanihy',
#   'Lat': -24.7,
#   'Lng': 44.75,
#   'Max Temp': 80.83,
#   'Humidity': 72,
#   'Cloudiness': 40,
#   'Wind Speed': 9.64,
#   'Country': 'MG',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Lardos',
#   'Lat': 36.0942,
#   'Lng': 28.0157,
#   'Max Temp': 64.4,
#   'Humidity': 72,
#   'Cloudiness': 75,
#   'Wind Speed': 5.75,
#   'Country': 'GR',
#   'Current Description': 'broken clouds'},
#  {'City': 'Pechenga',
#   'Lat': 69.5259,
#   'Lng': 31.1703,
#   'Max Temp': 24.8,
#   'Humidity': 80,
#   'Cloudiness': 75,
#   'Wind Speed': 20.71,
#   'Country': 'RU',
#   'Current Description': 'light snow'},
#  {'City': 'Morehead',
#   'Lat': 37.2711,
#   'Lng': -87.1764,
#   'Max Temp': 35.01,
#   'Humidity': 69,
#   'Cloudiness': 1,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Kattivakkam',
#   'Lat': 13.2167,
#   'Lng': 80.3167,
#   'Max Temp': 75.2,
#   'Humidity': 73,
#   'Cloudiness': 20,
#   'Wind Speed': 3.44,
#   'Country': 'IN',
#   'Current Description': 'haze'},
#  {'City': 'Fort Nelson',
#   'Lat': 58.8053,
#   'Lng': -122.7002,
#   'Max Temp': -36.4,
#   'Humidity': 67,
#   'Cloudiness': 20,
#   'Wind Speed': 2.3,
#   'Country': 'CA',
#   'Current Description': 'few clouds'},
#  {'City': 'Marshall',
#   'Lat': 34.3834,
#   'Lng': -86.3333,
#   'Max Temp': 43,
#   'Humidity': 56,
#   'Cloudiness': 1,
#   'Wind Speed': 3.44,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Luzhou',
#   'Lat': 28.8724,
#   'Lng': 105.4405,
#   'Max Temp': 58.77,
#   'Humidity': 64,
#   'Cloudiness': 97,
#   'Wind Speed': 2.19,
#   'Country': 'CN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Dalby',
#   'Lat': -27.1833,
#   'Lng': 151.2667,
#   'Max Temp': 71.01,
#   'Humidity': 91,
#   'Cloudiness': 75,
#   'Wind Speed': 4.76,
#   'Country': 'AU',
#   'Current Description': 'broken clouds'},
#  {'City': 'Nenjiang',
#   'Lat': 49.1833,
#   'Lng': 125.2167,
#   'Max Temp': -9.69,
#   'Humidity': 85,
#   'Cloudiness': 73,
#   'Wind Speed': 4.83,
#   'Country': 'CN',
#   'Current Description': 'broken clouds'},
#  {'City': 'Puyo',
#   'Lat': -1.4667,
#   'Lng': -77.9833,
#   'Max Temp': 71.6,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 3.29,
#   'Country': 'EC',
#   'Current Description': 'broken clouds'},
#  {'City': 'Columbia',
#   'Lat': 34.0007,
#   'Lng': -81.0348,
#   'Max Temp': 50,
#   'Humidity': 43,
#   'Cloudiness': 75,
#   'Wind Speed': 5.7,
#   'Country': 'US',
#   'Current Description': 'broken clouds'},
#  {'City': 'Banda Aceh',
#   'Lat': 5.5577,
#   'Lng': 95.3222,
#   'Max Temp': 78.94,
#   'Humidity': 83,
#   'Cloudiness': 44,
#   'Wind Speed': 8.95,
#   'Country': 'ID',
#   'Current Description': 'moderate rain'},
#  {'City': 'Stornoway',
#   'Lat': 58.2093,
#   'Lng': -6.3865,
#   'Max Temp': 39.2,
#   'Humidity': 70,
#   'Cloudiness': 75,
#   'Wind Speed': 20.71,
#   'Country': 'GB',
#   'Current Description': 'broken clouds'},
#  {'City': 'Olinda',
#   'Lat': -8.0089,
#   'Lng': -34.8553,
#   'Max Temp': 84.2,
#   'Humidity': 58,
#   'Cloudiness': 40,
#   'Wind Speed': 10.36,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Dharchula',
#   'Lat': 29.85,
#   'Lng': 80.5333,
#   'Max Temp': 45.07,
#   'Humidity': 47,
#   'Cloudiness': 0,
#   'Wind Speed': 9.33,
#   'Country': 'IN',
#   'Current Description': 'clear sky'},
#  {'City': 'Senanga',
#   'Lat': -16.1167,
#   'Lng': 23.2667,
#   'Max Temp': 83.79,
#   'Humidity': 61,
#   'Cloudiness': 52,
#   'Wind Speed': 1.66,
#   'Country': 'ZM',
#   'Current Description': 'broken clouds'},
#  {'City': 'Bikaner',
#   'Lat': 28.0167,
#   'Lng': 73.3,
#   'Max Temp': 60.44,
#   'Humidity': 31,
#   'Cloudiness': 0,
#   'Wind Speed': 6.53,
#   'Country': 'IN',
#   'Current Description': 'clear sky'},
#  {'City': 'Khandyga',
#   'Lat': 62.6667,
#   'Lng': 135.6,
#   'Max Temp': -27.35,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 1.57,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Martapura',
#   'Lat': -3.4167,
#   'Lng': 114.85,
#   'Max Temp': 78.8,
#   'Humidity': 94,
#   'Cloudiness': 100,
#   'Wind Speed': 3.44,
#   'Country': 'ID',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Bilibino',
#   'Lat': 68.0546,
#   'Lng': 166.4372,
#   'Max Temp': -9.67,
#   'Humidity': 83,
#   'Cloudiness': 0,
#   'Wind Speed': 2.42,
#   'Country': 'RU',
#   'Current Description': 'clear sky'},
#  {'City': 'Berwick',
#   'Lat': 41.0545,
#   'Lng': -76.2333,
#   'Max Temp': 35.01,
#   'Humidity': 51,
#   'Cloudiness': 9,
#   'Wind Speed': 5.99,
#   'Country': 'US',
#   'Current Description': 'clear sky'},
#  {'City': 'Pineville',
#   'Lat': 31.3224,
#   'Lng': -92.4343,
#   'Max Temp': 46.99,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 8.05,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Salinopolis',
#   'Lat': -0.6136,
#   'Lng': -47.3561,
#   'Max Temp': 84.45,
#   'Humidity': 72,
#   'Cloudiness': 31,
#   'Wind Speed': 11.77,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Turan',
#   'Lat': 16.0678,
#   'Lng': 108.2208,
#   'Max Temp': 69.8,
#   'Humidity': 88,
#   'Cloudiness': 75,
#   'Wind Speed': 1.14,
#   'Country': 'VN',
#   'Current Description': 'broken clouds'},
#  {'City': 'Inirida',
#   'Lat': 3.8653,
#   'Lng': -67.9239,
#   'Max Temp': 82.47,
#   'Humidity': 85,
#   'Cloudiness': 68,
#   'Wind Speed': 2.57,
#   'Country': 'CO',
#   'Current Description': 'broken clouds'},
#  {'City': 'Gerash',
#   'Lat': 27.6652,
#   'Lng': 54.1371,
#   'Max Temp': 69.8,
#   'Humidity': 37,
#   'Cloudiness': 0,
#   'Wind Speed': 3.38,
#   'Country': 'IR',
#   'Current Description': 'clear sky'},
#  {'City': 'Surt',
#   'Lat': 31.2089,
#   'Lng': 16.5887,
#   'Max Temp': 73,
#   'Humidity': 33,
#   'Cloudiness': 65,
#   'Wind Speed': 7.65,
#   'Country': 'LY',
#   'Current Description': 'broken clouds'},
#  {'City': 'Mamburao',
#   'Lat': 13.25,
#   'Lng': 120.6667,
#   'Max Temp': 76.95,
#   'Humidity': 71,
#   'Cloudiness': 65,
#   'Wind Speed': 8.34,
#   'Country': 'PH',
#   'Current Description': 'broken clouds'},
#  {'City': 'Bitung',
#   'Lat': 1.4451,
#   'Lng': 125.1824,
#   'Max Temp': 77,
#   'Humidity': 94,
#   'Cloudiness': 40,
#   'Wind Speed': 3.44,
#   'Country': 'ID',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Cao Bang',
#   'Lat': 22.6667,
#   'Lng': 106.25,
#   'Max Temp': 62.2,
#   'Humidity': 77,
#   'Cloudiness': 59,
#   'Wind Speed': 2.3,
#   'Country': 'VN',
#   'Current Description': 'broken clouds'},
#  {'City': 'Bessonovka',
#   'Lat': 53.3097,
#   'Lng': 45.0407,
#   'Max Temp': 3.96,
#   'Humidity': 92,
#   'Cloudiness': 100,
#   'Wind Speed': 11.01,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kondinskoye',
#   'Lat': 59.6481,
#   'Lng': 67.41,
#   'Max Temp': 34.72,
#   'Humidity': 97,
#   'Cloudiness': 100,
#   'Wind Speed': 13.04,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Makakilo City',
#   'Lat': 21.3469,
#   'Lng': -158.0858,
#   'Max Temp': 62.6,
#   'Humidity': 82,
#   'Cloudiness': 90,
#   'Wind Speed': 4.61,
#   'Country': 'US',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Warrington',
#   'Lat': 53.3925,
#   'Lng': -2.5802,
#   'Max Temp': 39.99,
#   'Humidity': 93,
#   'Cloudiness': 94,
#   'Wind Speed': 3,
#   'Country': 'GB',
#   'Current Description': 'light rain'},
#  {'City': 'Asfi',
#   'Lat': 32.2994,
#   'Lng': -9.2372,
#   'Max Temp': 58.44,
#   'Humidity': 70,
#   'Cloudiness': 84,
#   'Wind Speed': 15.93,
#   'Country': 'MA',
#   'Current Description': 'broken clouds'},
#  {'City': 'Doha',
#   'Lat': 25.2867,
#   'Lng': 51.5333,
#   'Max Temp': 72,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 4.61,
#   'Country': 'QA',
#   'Current Description': 'clear sky'},
#  {'City': 'Le Port',
#   'Lat': -20.9373,
#   'Lng': 55.2919,
#   'Max Temp': 80.6,
#   'Humidity': 78,
#   'Cloudiness': 75,
#   'Wind Speed': 9.22,
#   'Country': 'RE',
#   'Current Description': 'light rain'},
#  {'City': 'Tonneins',
#   'Lat': 44.3921,
#   'Lng': 0.3124,
#   'Max Temp': 53.6,
#   'Humidity': 87,
#   'Cloudiness': 90,
#   'Wind Speed': 9.22,
#   'Country': 'FR',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Belyy Yar',
#   'Lat': 53.6039,
#   'Lng': 91.3903,
#   'Max Temp': 12.2,
#   'Humidity': 85,
#   'Cloudiness': 100,
#   'Wind Speed': 2.24,
#   'Country': 'RU',
#   'Current Description': 'mist'},
#  {'City': 'Husavik',
#   'Lat': 66.0449,
#   'Lng': -17.3389,
#   'Max Temp': 33.8,
#   'Humidity': 64,
#   'Cloudiness': 75,
#   'Wind Speed': 6.91,
#   'Country': 'IS',
#   'Current Description': 'broken clouds'},
#  {'City': 'North Platte',
#   'Lat': 41.1239,
#   'Lng': -100.7654,
#   'Max Temp': 12.2,
#   'Humidity': 73,
#   'Cloudiness': 90,
#   'Wind Speed': 14.97,
#   'Country': 'US',
#   'Current Description': 'light snow'},
#  {'City': 'Maceio',
#   'Lat': -9.6658,
#   'Lng': -35.7353,
#   'Max Temp': 89.6,
#   'Humidity': 58,
#   'Cloudiness': 40,
#   'Wind Speed': 6.91,
#   'Country': 'BR',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Impfondo',
#   'Lat': 1.6381,
#   'Lng': 18.0667,
#   'Max Temp': 85.8,
#   'Humidity': 51,
#   'Cloudiness': 100,
#   'Wind Speed': 2.86,
#   'Country': 'CG',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Kuznechnoye',
#   'Lat': 61.12,
#   'Lng': 29.8686,
#   'Max Temp': 10.99,
#   'Humidity': 94,
#   'Cloudiness': 29,
#   'Wind Speed': 7.2,
#   'Country': 'RU',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Puerto Escondido',
#   'Lat': 15.85,
#   'Lng': -97.0667,
#   'Max Temp': 82.4,
#   'Humidity': 74,
#   'Cloudiness': 40,
#   'Wind Speed': 7.25,
#   'Country': 'MX',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Gejiu',
#   'Lat': 23.306,
#   'Lng': 103.1635,
#   'Max Temp': 47.79,
#   'Humidity': 100,
#   'Cloudiness': 62,
#   'Wind Speed': 4.7,
#   'Country': 'CN',
#   'Current Description': 'broken clouds'},
#  {'City': 'Oskarshamn',
#   'Lat': 57.2645,
#   'Lng': 16.4484,
#   'Max Temp': 19,
#   'Humidity': 85,
#   'Cloudiness': 89,
#   'Wind Speed': 5.01,
#   'Country': 'SE',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Sorbhog',
#   'Lat': 26.5,
#   'Lng': 90.8667,
#   'Max Temp': 67.57,
#   'Humidity': 44,
#   'Cloudiness': 87,
#   'Wind Speed': 2.84,
#   'Country': 'IN',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Nandgaon',
#   'Lat': 20.3167,
#   'Lng': 74.65,
#   'Max Temp': 72.25,
#   'Humidity': 26,
#   'Cloudiness': 0,
#   'Wind Speed': 9.01,
#   'Country': 'IN',
#   'Current Description': 'clear sky'},
#  {'City': 'Maniitsoq',
#   'Lat': 65.4167,
#   'Lng': -52.9,
#   'Max Temp': 23.74,
#   'Humidity': 76,
#   'Cloudiness': 0,
#   'Wind Speed': 8.79,
#   'Country': 'GL',
#   'Current Description': 'clear sky'},
#  {'City': 'Mogadishu',
#   'Lat': 2.0371,
#   'Lng': 45.3438,
#   'Max Temp': 77.56,
#   'Humidity': 78,
#   'Cloudiness': 0,
#   'Wind Speed': 19.17,
#   'Country': 'SO',
#   'Current Description': 'clear sky'},
#  {'City': 'Karaton',
#   'Lat': -6.3424,
#   'Lng': 106.1045,
#   'Max Temp': 84.99,
#   'Humidity': 83,
#   'Cloudiness': 75,
#   'Wind Speed': 2.3,
#   'Country': 'ID',
#   'Current Description': 'broken clouds'},
#  {'City': 'Nhulunbuy',
#   'Lat': -12.2333,
#   'Lng': 136.7667,
#   'Max Temp': 80.6,
#   'Humidity': 83,
#   'Cloudiness': 90,
#   'Wind Speed': 14.97,
#   'Country': 'AU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Port Keats',
#   'Lat': -14.25,
#   'Lng': 129.55,
#   'Max Temp': 83.12,
#   'Humidity': 79,
#   'Cloudiness': 70,
#   'Wind Speed': 14.63,
#   'Country': 'AU',
#   'Current Description': 'light rain'},
#  {'City': 'Plettenberg Bay',
#   'Lat': -34.0527,
#   'Lng': 23.3716,
#   'Max Temp': 73.13,
#   'Humidity': 69,
#   'Cloudiness': 10,
#   'Wind Speed': 5.48,
#   'Country': 'ZA',
#   'Current Description': 'clear sky'},
#  {'City': 'Pochutla',
#   'Lat': 15.7432,
#   'Lng': -96.4661,
#   'Max Temp': 82,
#   'Humidity': 78,
#   'Cloudiness': 20,
#   'Wind Speed': 6.31,
#   'Country': 'MX',
#   'Current Description': 'few clouds'},
#  {'City': 'Kurilsk',
#   'Lat': 45.2333,
#   'Lng': 147.8833,
#   'Max Temp': 22.98,
#   'Humidity': 95,
#   'Cloudiness': 100,
#   'Wind Speed': 12.35,
#   'Country': 'RU',
#   'Current Description': 'overcast clouds'},
#  {'City': 'Pombas',
#   'Lat': 17.1503,
#   'Lng': -25.0201,
#   'Max Temp': 75.2,
#   'Humidity': 53,
#   'Cloudiness': 40,
#   'Wind Speed': 28.77,
#   'Country': 'CV',
#   'Current Description': 'scattered clouds'},
#  {'City': 'Sarangpur',
#   'Lat': 23.5667,
#   'Lng': 76.4667,
#   'Max Temp': 59.31,
#   'Humidity': 34,
#   'Cloudiness': 0,
#   'Wind Speed': 8.03,
#   'Country': 'IN',
#   'Current Description': 'clear sky'},
#  {'City': 'Karangasem',
#   'Lat': -8.45,
#   'Lng': 115.6167,
#   'Max Temp': 78.8,
#   'Humidity': 94,
#   'Cloudiness': 20,
#   'Wind Speed': 4.61,
#   'Country': 'ID',
#   'Current Description': 'few clouds'}]

# %%
# Convert the array of dictionaries to a Pandas DataFrame. 6.2.7
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mar Del Plata -38.0023  -57.5575     73.00        68          75
# 1           Hithadhoo  -0.6000   73.0833     81.99        76         100
# 2                Lebu -37.6167  -73.6500     62.74        77          92
# 3               Bluff -46.6000  168.3333     54.27        86           9
# 4          Lavrentiya  65.5833 -171.0000     -1.66        86          96
# 5             Hualmay -11.0964  -77.6139     74.75        66          94
# 6  San Rafael Del Sur  11.8485  -86.4384     82.40        65          20
# 7             Te Anau -45.4167  167.7167     52.79        85          24
# 8             Ushuaia -54.8000  -68.3000     51.80        50          40
# 9      Severo-Kurilsk  50.6789  156.1250     19.58        94         100
#
#    Wind Speed Country Current Description
# 0       13.80      AR       broken clouds
# 1       14.25      MV     overcast clouds
# 2        6.29      CL     overcast clouds
# 3        1.45      NZ           clear sky
# 4        6.89      RU     overcast clouds
# 5        8.43      PE     overcast clouds
# 6        6.91      NI          few clouds
# 7        0.94      NZ          few clouds
# 8       19.57      AR    scattered clouds
# 9       16.98      RU          light snow

# %%
# Reorder the DataFrame
city_data_df = city_data_df[['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness', 'Wind Speed', 
                              'Current Description']]
city_data_df.head(10)
# Out:
#                  City Country      Lat       Lng  Max Temp  Humidity  \
# 0       Mar Del Plata      AR -38.0023  -57.5575     73.00        68
# 1           Hithadhoo      MV  -0.6000   73.0833     81.99        76
# 2                Lebu      CL -37.6167  -73.6500     62.74        77
# 3               Bluff      NZ -46.6000  168.3333     54.27        86
# 4          Lavrentiya      RU  65.5833 -171.0000     -1.66        86
# 5             Hualmay      PE -11.0964  -77.6139     74.75        66
# 6  San Rafael Del Sur      NI  11.8485  -86.4384     82.40        65
# 7             Te Anau      NZ -45.4167  167.7167     52.79        85
# 8             Ushuaia      AR -54.8000  -68.3000     51.80        50
# 9      Severo-Kurilsk      RU  50.6789  156.1250     19.58        94
#
#    Cloudiness  Wind Speed Current Description
# 0          75       13.80       broken clouds
# 1         100       14.25     overcast clouds
# 2          92        6.29     overcast clouds
# 3           9        1.45           clear sky
# 4          96        6.89     overcast clouds
# 5          94        8.43     overcast clouds
# 6          20        6.91          few clouds
# 7          24        0.94          few clouds
# 8          40       19.57    scattered clouds
# 9         100       16.98          light snow

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
